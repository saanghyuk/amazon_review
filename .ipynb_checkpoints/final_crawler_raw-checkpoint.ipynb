# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from urllib.parse import quote

# %% [markdown]
# ### Input Search_Query

# %%
search_query="tv"

# %% [markdown]
# ### Crawling

# %%
base_url="https://www.amazon.com/s?k="

# %%
url=base_url+search_query

# %%
url
# Out:
# 'https://www.amazon.com/s?k=tv'

# %%
header={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.90 Safari/537.36'}
search_response=requests.get(url,headers=header)
search_response.status_code
# Out:
# 200

# %%
search_response.text
# Out:
# '<!DOCTYPE html>\n<!--[if lt IE 7]> <html lang="en-us" class="a-no-js a-lt-ie9 a-lt-ie8 a-lt-ie7"> <![endif]-->\n<!--[if IE 7]>    <html lang="en-us" class="a-no-js a-lt-ie9 a-lt-ie8"> <![endif]-->\n<!--[if IE 8]>    <html lang="en-us" class="a-no-js a-lt-ie9"> <![endif]-->\n<!--[if gt IE 8]><!-->\n<html class="a-no-js" lang="en-us"><!--<![endif]--><head>\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n<meta charset="utf-8">\n<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n<title dir="ltr">Robot Check</title>\n<meta name="viewport" content="width=device-width">\n<link rel="stylesheet" href="https://images-na.ssl-images-amazon.com/images/G/01/AUIClients/AmazonUI-3c913031596ca78a3768f4e934b1cc02ce238101.secure.min._V1_.css">\n<script>\n\nif (true === true) {\n    var ue_t0 = (+ new Date()),\n        ue_csm = window,\n        ue = { t0: ue_t0, d: function() { return (+new Date() - ue_t0); } },\n        ue_furl = "fls-na.amazon.com",\n        ue_mid = "ATVPDKIKX0DER",\n        ue_sid = (document.cookie.match(/session-id=([0-9-]+)/) || [])[1],\n        ue_sn = "opfcaptcha.amazon.com",\n        ue_id = \'EY4M34WGYD4Y38A99X26\';\n}\n</script>\n</head>\n<body>\n\n<!--\n        To discuss automated access to Amazon data please contact api-services-support@amazon.com.\n        For information about migrating to our APIs refer to our Marketplace APIs at https://developer.amazonservices.com/ref=rm_c_sv, or our Product Advertising API at https://affiliate-program.amazon.com/gp/advertising/api/detail/main.html/ref=rm_c_ac for advertising use cases.\n-->\n\n<!--\nCorreios.DoNotSend\n-->\n\n<div class="a-container a-padding-double-large" style="min-width:350px;padding:44px 0 !important">\n\n    <div class="a-row a-spacing-double-large" style="width: 350px; margin: 0 auto">\n\n        <div class="a-row a-spacing-medium a-text-center"><i class="a-icon a-logo"></i></div>\n\n        <div class="a-box a-alert a-alert-info a-spacing-base">\n            <div class="a-box-inner">\n                <i class="a-icon a-icon-alert"></i>\n                <h4>Enter the characters you see below</h4>\n                <p class="a-last">Sorry, we just need to make sure you\'re not a robot. For best results, please make sure your browser is accepting cookies.</p>\n                </div>\n            </div>\n\n            <div class="a-section">\n\n                <div class="a-box a-color-offset-background">\n                    <div class="a-box-inner a-padding-extra-large">\n\n                        <form method="get" action="/errors/validateCaptcha" name="">\n                            <input type=hidden name="amzn" value="NTlgBhRaj9KkF2/foh0CEg==" /><input type=hidden name="amzn-r" value="&#047;s?k&#061;tv" />\n                            <div class="a-row a-spacing-large">\n                                <div class="a-box">\n                                    <div class="a-box-inner">\n                                        <h4>Type the characters you see in this image:</h4>\n                                        <div class="a-row a-text-center">\n                                            <img src="https://images-na.ssl-images-amazon.com/captcha/sgkknrsj/Captcha_oxpjnahkvc.jpg">\n                                        </div>\n                                        <div class="a-row a-spacing-base">\n                                            <div class="a-row">\n                                                <div class="a-column a-span6">\n                                                </div>\n                                                <div class="a-column a-span6 a-span-last a-text-right">\n                                                    <a onclick="window.location.reload()">Try different image</a>\n                                                </div>\n                                            </div>\n                                            <input autocomplete="off" spellcheck="false" pla ...

# %% [markdown]
# #### A function to get the content of the page of required query

# %%
# cookie={} # insert request cookies within{}
# def getAmazonSearch(search_query):
#     url="https://www.amazon.com/s?k="+search_query
#     print(url)
#     page=requests.get(url,cookies=cookie,headers=header)
#     if page.status_code==200:
#         print("yes")
#         return page
#     else:
#         print("No")
#         return "Error"

# %%
cookie={} # insert request cookies within{}
def getAmazonSearch(search_query):
    url="https://www.amazon.com/s?k="+search_query
    print(url)
    page=requests.get(url,cookies=cookie,headers=header)
    if page.status_code==200:
        print("yes")
        return page
    else:
        print("No")
        return "Error"

# %% [markdown]
# #### A function to get the contents of individual product pages using 'data-asin' number (unique identification number)

# %%
def Searchasin(asin):
    url="https://www.amazon.com/dp/"+asin
    print(url)
    page=requests.get(url,cookies=cookie,headers=header)
    print(page)
    if page.status_code==200:
        return page
    else:
        return "Error"

# %% [markdown]
# #### A function to pass on the link of 'see all reviews' and extract the content

# %%
def Searchreviews(review_link):
    url="https://www.amazon.com"+review_link
    print(url)
    page=requests.get(url,cookies=cookie,headers=header)
    if page.status_code==200:
        return page
    else:
        return "Error"

# %% [markdown]
# ### Product Name extraction

# %%
product_names=[]
data_asin = []

# %%
# product_names=[]
# response=getAmazonSearch('tv')
# soup=BeautifulSoup(response.content)
    
# for i in soup.findAll("span",{'class':'a-size-medium a-color-base a-text-normal'}): # the tag which is common for all the names of products
#     product_names.append(i.text) #adding the product names to the list

# %%
import time

# %%
product_names=[]
data_asin = []
for i in range(1,21):
    response=getAmazonSearch(search_query+'&page='+str(i))
    time.sleep(1)
    soup=BeautifulSoup(response.content)
    print("hello")
    for i in soup.findAll("span",{'class':'a-size-medium a-color-base a-text-normal'}):
        print("hi")
        product_names.append(i.text) #adding the product names to the list

    for i in soup.findAll("div", {"class":"s-result-item"}):
        print("bye")
        if i['data-asin']:
            data_asin.append(i['data-asin'])
# Out:
# https://www.amazon.com/s?k=tv&page=1
# yes
# hello
# https://www.amazon.com/s?k=tv&page=2
# yes
# hello
# https://www.amazon.com/s?k=tv&page=3
# yes
# hello
# https://www.amazon.com/s?k=tv&page=4
# yes
# hello
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# bye
# bye
# bye
# bye
# bye
# bye
# bye
# bye
# bye
# bye
# bye
# bye
# bye
# bye
# bye
# bye
# https://www.amazon.com/s?k=tv&page=5
# yes
# hello
# https://www.amazon.com/s?k=tv&page=6
# yes
# hello
# https://www.amazon.com/s?k=tv&page=7
# yes
# hello
# https://www.amazon.com/s?k=tv&page=8
# yes
# hello
# https://www.amazon.com/s?k=tv&page=9
# yes
# hello
# https://www.amazon.com/s?k=tv&page=10
# yes
# hello
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# bye
# bye
# bye
# bye
# bye
# bye
# bye
# bye
# bye
# bye
# bye
# bye
# bye
# bye
# bye
# bye
# https://www.amazon.com/s?k=tv&page=11
# yes
# hello
# https://www.amazon.com/s?k=tv&page=12
# yes
# hello
# https://www.amazon.com/s?k=tv&page=13
# yes
# hello
# https://www.amazon.com/s?k=tv&page=14
# yes
# hello
# https://www.amazon.com/s?k=tv&page=15
# yes
# hello
# https://www.amazon.com/s?k=tv&page=16
# yes
# hello
# https://www.amazon.com/s?k=tv&page=17
# yes
# hello
# https://www.amazon.com/s?k=tv&page=18
# yes
# hello
# https://www.amazon.com/s?k=tv&page=19
# yes
# hello
# https://www.amazon.com/s?k=tv&page=20
# yes
# hello

# %%
len(data_asin)
# Out:
# 258

# %% [markdown]
# When scrawling the all pages of product list in specific search query, I could discover that there are same products in the list. <br>
# Therefore, I needed to remove the same product in the list of ASIN.

# %%
asin_list = list(dict.fromkeys(data_asin) )

# %%
len(asin_list)
# Out:
# 258

# %%
asin_list
# Out:
# ['B07G9XZ83W',
#  'B07SC4JSGZ',
#  'B07W1121LW',
#  'B01LXHXGZX',
#  'B01N2Z17MS',
#  'B07CL4GLQW',
#  'B01CG8NFQO',
#  'B08129Q548',
#  'B07T4M2PSS',
#  'B00IZCW4QI',
#  'B07T745LPZ',
#  'B074PDYLCZ',
#  'B07Y7PDQ4N',
#  'B07D289ZCV',
#  'B077J8R84V',
#  'B082BNFBY1',
#  'B07D55BHT4',
#  'B0827F4DM2',
#  'B07GDRCPVX',
#  'B07K3275ZG',
#  'B01NBA9HT2',
#  'B07CRDC5BZ',
#  'B01CUT5ZZI',
#  'B07LH61TZB',
#  'B073JP6WK4',
#  'B07RWVXPGL',
#  'B07WTQYRPH',
#  'B07FQ24C67',
#  'B0813VD16M',
#  'B07FNCNKWD',
#  'B07H626STV',
#  'B00TWFHCLE',
#  'B07CBSGR5F',
#  'B083Y662J9',
#  'B07NF9BZ1J',
#  'B07ZTR5MBV',
#  'B07Y8SQQLG',
#  'B0024R4B5C',
#  'B07VFNV6S3',
#  'B07J1TZ6M9',
#  'B07S1YNJS4',
#  'B07RQ7NK49',
#  'B082QVSXQM',
#  'B07T3HYFB9',
#  'B07CT4QCBK',
#  'B07TJ9K7PM',
#  'B06XNMQQCP',
#  'B07J1WTL8V',
#  'B07XF2P9KR',
#  'B08239VDZB',
#  'B082G2YD2B',
#  'B07R11T5MC',
#  'B07WH82M8F',
#  'B0083IYZB6',
#  'B014U7U0T4',
#  'B07XPFMZ5G',
#  'B07DP64MTR',
#  'B07QV1Q3WW',
#  'B07FSCRJ6N',
#  'B081VRZXTC',
#  'B0716X489L',
#  'B077TD252L',
#  'B07KGPWG3M',
#  'B06X3VH4VK',
#  'B07Y6Q2QB8',
#  'B07Z9LG56V',
#  'B0849YJQ7N',
#  'B07JVQY8W1',
#  'B00J41R2PC',
#  'B083ZJLBBG',
#  'B07G8N33P8',
#  'B07ZXK61VN',
#  'B074NL8B3S',
#  'B07XPG8SWJ',
#  'B07VZ6NTY1',
#  'B07Q4PP74V',
#  'B01M1D0KL1',
#  'B01GU9EFVY',
#  'B07195FH8G',
#  'B075FDWSHT',
#  'B07WZWLRJ8',
#  'B06XQW5FJH',
#  'B01A0LGS7W',
#  'B004GISARW',
#  'B07WYJCB7R',
#  'B073HVJ9XX',
#  'B07YSWQKLK',
#  'B07R2FJRX1',
#  'B07ZYV3LP3',
#  'B07ZSGPXZG',
#  'B07Y5Q69JS',
#  'B00CDGSNLW',
#  'B07Q8T65SQ',
#  'B07DGCJ3KY',
#  'B07X1V3LWY',
#  'B01N6HUSBU',
#  'B07ZHP636T',
#  'B07RY2CJRG',
#  'B084JRG2FW',
#  'B07Q2Y5N9F',
#  'B08116BZMS',
#  'B07YMKB782',
#  'B019QGNPGY',
#  'B07BKLD5HQ',
#  'B07P1FQW4P',
#  'B019PZDJ7Q',
#  'B07WWYSLFF',
#  'B00LUZ91D6',
#  'B07Y19B25F',
#  'B07WJL885G',
#  'B07RN7ZM78',
#  'B07X9Z3118',
#  'B07BB6T1TT',
#  'B07VVQZ9SG',
#  'B07X8VLZ4T',
#  '1615932933',
#  'B07Y2GFCJ6',
#  'B076K7FZH3',
#  'B0742DQJBC',
#  'B07RPB3QS8',
#  'B010KKCXZ4',
#  'B07MC17V5L',
#  'B07XD996DF',
#  'B07SB94SNG',
#  'B06XSSQSNL',
#  'B07VJMNCF2',
#  'B07C7M8WQC',
#  'B07ZZHN2LP',
#  'B07W3MBG3Y',
#  'B01LPN0MFS',
#  'B07WYKGDJT',
#  'B077L2NFL3',
#  'B00RV3RHX2',
#  'B07ZSGYCJD',
#  'B07TGLH7XY',
#  'B002PZGB38',
#  'B083F5553H',
#  'B00PBBTN9W',
#  'B07XTHCSXX',
#  'B01L7TDON2',
#  'B07ZZBWLHZ',
#  'B081J6ZNKH',
#  'B07Y6LYCJK',
#  'B013J9U1AC',
#  'B082CB9R6J',
#  'B07WJDMT7M',
#  'B07MWFMS6Y',
#  'B081SZVTRW',
#  'B07C2QL49T',
#  'B01LYDNOB0',
#  'B081D7H5FV',
#  'B0767PW5W5',
#  'B07XSCLRJB',
#  'B07RSQYPJ8',
#  'B07S1QCS2Z',
#  'B0784HGZY5',
#  'B07QBD138X',
#  'B01CTVC4OC',
#  'B07T5JW7RT',
#  'B07F9VYT5G',
#  'B079Q959J6',
#  'B079NHBRT1',
#  'B00NO3ER7W',
#  'B07L1BNWKC',
#  'B00CUEEE8I',
#  'B07F2YLMF5',
#  'B07SPLKGCN',
#  'B07ZXSQYNR',
#  'B07XZMMHZ5',
#  '1119671469',
#  'B004VCT770',
#  'B07SFT2KRX',
#  'B084JD1KW8',
#  'B07MB66PBD',
#  'B012HSMOEC',
#  'B01CJ4IM4A',
#  'B01LX4TR1R',
#  'B01MR2AG6Z',
#  'B07J5S1BGM',
#  'B079TT1C7Z',
#  'B01CIVHI80',
#  'B07Q2XFFM2',
#  'B07QCKNSXN',
#  'B078Y77VQ7',
#  'B08426X2PF',
#  'B07N31HR6C',
#  'B07ZXL1BZJ',
#  'B07Y67NG1J',
#  'B00JPLKZPK',
#  'B07L449TK3',
#  'B07JP9TNQT',
#  'B07DC77DPT',
#  'B07BFRHKPG',
#  'B0847B7S7M',
#  'B07Q3X7S15',
#  'B07ZXKF7ZN',
#  'B084BNBLQS',
#  'B07Q3RM4QT',
#  'B07L7YCC15',
#  'B00YK6IIJU',
#  'B07679GGJG',
#  'B01N4TOXFG',
#  'B0844YL3LZ',
#  'B076X8FKXP',
#  'B07QFLD23P',
#  'B07QNGWBSJ',
#  'B0845WBR6H',
#  'B00E3V3HZW',
#  'B07W314CFW',
#  'B014IUT2CO',
#  'B07F6635BS',
#  'B00NDWJKSU',
#  'B07M8GHNK4',
#  'B00BCS1EM2',
#  'B07WQGJBBB',
#  'B07BDNQNB5',
#  'B07ZXKRQS8',
#  'B07ZXKYHLY',
#  'B07FTV3Z55',
#  'B07KMNCQTY',
#  'B07RQ8BRP6',
#  'B01MS7OMT4',
#  'B07YSMD3Z9',
#  'B07CWF6VH1',
#  'B07ZXV9N1X',
#  'B07YSX1R3X',
#  'B07S59M6KX',
#  'B07RN82K6F',
#  'B07CMK6KG9',
#  'B019PZDJEE',
#  'B00CYRMRMQ',
#  'B01FV7Z1R8',
#  'B07VXWTNXN',
#  'B01I22DQCG',
#  'B07VPC8QC6',
#  'B078Z1DYD9',
#  'B07Y6L696X',
#  'B07WQM6GLT',
#  'B01LR31Y44',
#  'B07Y6PBSYL',
#  'B01N17YYW0',
#  'B07WW1C9CH',
#  'B07D7GXL97',
#  'B0042K4ZZK',
#  'B000A7W3YO',
#  'B07Q6VGBNN',
#  'B014I63EXQ',
#  'B07YXD24Z4',
#  'B07K77Z4JX',
#  'B07HLFCYRV',
#  'B07ZXKDXL8',
#  'B075FGMYPM',
#  'B07Y2GMX3H',
#  'B07XCPNYXX',
#  'B073JYHTV6',
#  'B01N4ULLGB',
#  'B07H9G49SQ',
#  'B07PPNV2LR']

# %%
data_asin = asin_list

# %%
len(data_asin)
# Out:
# 258

# %%
def Searchasin(asin):
    url="https://www.amazon.com/dp/"+asin
    print(url)
    page=requests.get(url,cookies=cookie,headers=header)
    if page.status_code==200:
        return page
    else:
        return "Error"

# %%
link=[]
for i in range(len(data_asin)):
    print(i)
    response=Searchasin(data_asin[i])
    soup=BeautifulSoup(response.content)
    time.sleep(1)
    for i in soup.findAll("a",{'data-hook':"see-all-reviews-link-foot"}):
        print(i['href'])
        link.append(i['href'])
    
#     if soup.find("a",{'data-hook':"see-all-reviews-link-foot"}):
#         link.append(soup.find("a",{'data-hook':"see-all-reviews-link-foot"})['href'])
#         print("There is a button")
#     else:
#         print("There is no see all button")
# Out:
# 0
# https://www.amazon.com/dp/B07G9XZ83W
# 1
# https://www.amazon.com/dp/B07SC4JSGZ
# 2
# https://www.amazon.com/dp/B07W1121LW
# 3
# https://www.amazon.com/dp/B01LXHXGZX
# 4
# https://www.amazon.com/dp/B01N2Z17MS
# 5
# https://www.amazon.com/dp/B07CL4GLQW
# 6
# https://www.amazon.com/dp/B01CG8NFQO
# 7
# https://www.amazon.com/dp/B08129Q548
# 8
# https://www.amazon.com/dp/B07T4M2PSS
# 9
# https://www.amazon.com/dp/B00IZCW4QI
# 10
# https://www.amazon.com/dp/B07T745LPZ
# 11
# https://www.amazon.com/dp/B074PDYLCZ
# 12
# https://www.amazon.com/dp/B07Y7PDQ4N
# 13
# https://www.amazon.com/dp/B07D289ZCV
# 14
# https://www.amazon.com/dp/B077J8R84V
# 15
# https://www.amazon.com/dp/B082BNFBY1
# 16
# https://www.amazon.com/dp/B07D55BHT4
# 17
# https://www.amazon.com/dp/B0827F4DM2
# 18
# https://www.amazon.com/dp/B07GDRCPVX
# 19
# https://www.amazon.com/dp/B07K3275ZG
# 20
# https://www.amazon.com/dp/B01NBA9HT2
# 21
# https://www.amazon.com/dp/B07CRDC5BZ
# 22
# https://www.amazon.com/dp/B01CUT5ZZI
# 23
# https://www.amazon.com/dp/B07LH61TZB
# 24
# https://www.amazon.com/dp/B073JP6WK4
# 25
# https://www.amazon.com/dp/B07RWVXPGL
# 26
# https://www.amazon.com/dp/B07WTQYRPH
# 27
# https://www.amazon.com/dp/B07FQ24C67
# 28
# https://www.amazon.com/dp/B0813VD16M
# 29
# https://www.amazon.com/dp/B07FNCNKWD
# 30
# https://www.amazon.com/dp/B07H626STV
# 31
# https://www.amazon.com/dp/B00TWFHCLE
# 32
# https://www.amazon.com/dp/B07CBSGR5F
# /Free-Signal-TV-Transit-Powered/product-reviews/B07CBSGR5F?reviewerType=all_reviews
# 33
# https://www.amazon.com/dp/B083Y662J9
# 34
# https://www.amazon.com/dp/B07NF9BZ1J
# 35
# https://www.amazon.com/dp/B07ZTR5MBV
# 36
# https://www.amazon.com/dp/B07Y8SQQLG
# 37
# https://www.amazon.com/dp/B0024R4B5C
# 38
# https://www.amazon.com/dp/B07VFNV6S3
# 39
# https://www.amazon.com/dp/B07J1TZ6M9
# 40
# https://www.amazon.com/dp/B07S1YNJS4
# 41
# https://www.amazon.com/dp/B07RQ7NK49
# 42
# https://www.amazon.com/dp/B082QVSXQM
# 43
# https://www.amazon.com/dp/B07T3HYFB9
# 44
# https://www.amazon.com/dp/B07CT4QCBK
# 45
# https://www.amazon.com/dp/B07TJ9K7PM
# 46
# https://www.amazon.com/dp/B06XNMQQCP
# 47
# https://www.amazon.com/dp/B07J1WTL8V
# 48
# https://www.amazon.com/dp/B07XF2P9KR
# 49
# https://www.amazon.com/dp/B08239VDZB
# 50
# https://www.amazon.com/dp/B082G2YD2B
# 51
# https://www.amazon.com/dp/B07R11T5MC
# 52
# https://www.amazon.com/dp/B07WH82M8F
# 53
# https://www.amazon.com/dp/B0083IYZB6
# 54
# https://www.amazon.com/dp/B014U7U0T4
# 55
# https://www.amazon.com/dp/B07XPFMZ5G
# 56
# https://www.amazon.com/dp/B07DP64MTR
# 57
# https://www.amazon.com/dp/B07QV1Q3WW
# 58
# https://www.amazon.com/dp/B07FSCRJ6N
# 59
# https://www.amazon.com/dp/B081VRZXTC
# 60
# https://www.amazon.com/dp/B0716X489L
# 61
# https://www.amazon.com/dp/B077TD252L
# 62
# https://www.amazon.com/dp/B07KGPWG3M
# 63
# https://www.amazon.com/dp/B06X3VH4VK
# 64
# https://www.amazon.com/dp/B07Y6Q2QB8
# 65
# https://www.amazon.com/dp/B07Z9LG56V
# 66
# https://www.amazon.com/dp/B0849YJQ7N
# 67
# https://www.amazon.com/dp/B07JVQY8W1
# 68
# https://www.amazon.com/dp/B00J41R2PC
# 69
# https://www.amazon.com/dp/B083ZJLBBG
# 70
# https://www.amazon.com/dp/B07G8N33P8
# 71
# https://www.amazon.com/dp/B07ZXK61VN
# 72
# https://www.amazon.com/dp/B074NL8B3S
# /oCOSMO-CE3220-32-720p-LED/product-reviews/B074NL8B3S?reviewerType=all_reviews
# 73
# https://www.amazon.com/dp/B07XPG8SWJ
# 74
# https://www.amazon.com/dp/B07VZ6NTY1
# 75
# https://www.amazon.com/dp/B07Q4PP74V
# 76
# https://www.amazon.com/dp/B01M1D0KL1
# 77
# https://www.amazon.com/dp/B01GU9EFVY
# 78
# https://www.amazon.com/dp/B07195FH8G
# 79
# https://www.amazon.com/dp/B075FDWSHT
# 80
# https://www.amazon.com/dp/B07WZWLRJ8
# 81
# https://www.amazon.com/dp/B06XQW5FJH
# 82
# https://www.amazon.com/dp/B01A0LGS7W
# 83
# https://www.amazon.com/dp/B004GISARW
# 84
# https://www.amazon.com/dp/B07WYJCB7R
# 85
# https://www.amazon.com/dp/B073HVJ9XX
# /Jensen-JE3217-Television-Integrated-Performance/product-reviews/B073HVJ9XX?reviewerType=all_reviews
# 86
# https://www.amazon.com/dp/B07YSWQKLK
# 87
# https://www.amazon.com/dp/B07R2FJRX1
# 88
# https://www.amazon.com/dp/B07ZYV3LP3
# 89
# https://www.amazon.com/dp/B07ZSGPXZG
# 90
# https://www.amazon.com/dp/B07Y5Q69JS
# 91
# https://www.amazon.com/dp/B00CDGSNLW
# 92
# https://www.amazon.com/dp/B07Q8T65SQ
# /Samsung-UN43RU7100FXZA-Universal-SurgePro-6-Outlet/product-reviews/B07Q8T65SQ?reviewerType=all_reviews
# 93
# https://www.amazon.com/dp/B07DGCJ3KY
# 94
# https://www.amazon.com/dp/B07X1V3LWY

# %% [markdown]
# The number of link and the number of ASIN can be different, because there are many products which have no review.

# %%
len(link)
# Out:
# 17

# %%
# urls=[]
# titles = []
search_query_list = []
reviews=[]
# ratings=[]
# dates=[]

for j in range(len(link)):
    print(j, 'th started')
    for k in range(1, 2):
        response=Searchreviews(link[j]+'&pageNumber='+str(k))
        soup=BeautifulSoup(response.content)
        if soup.find('div', 
                     {"class" : "a-section a-spacing-top-large a-text-center no-reviews-section"}):
            print('No review, Pass')
            break
        
        else: 
            print('There is review')
#           for i in soup.findAll("span",{'data-hook':"review-body"}):
            for i in soup.findAll("span",{'data-hook':"a-size-base review-text review-text-content"}):
            
                reviews.append(i.text)
                search_query_list.append(search_query)
# Out:
# 0 th started
# https://www.amazon.com/Acer-TC-885-UA92-Desktop-i5-9400-802-11AC/product-reviews/B07R8WJMW6/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 1 th started
# https://www.amazon.com/HP-21-5-Inch-Computer-A4-9125-22-c0010/product-reviews/B07VDJ5RVF/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 2 th started
# https://www.amazon.com/Acer-Display-Graphics-Keyboard-A515-43-R19L/product-reviews/B07RF1XD36/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 3 th started
# https://www.amazon.com/CYBERPOWERPC-Xtreme-i5-9400F-GeForce-GXiVR8060A8/product-reviews/B07VGJDKZ4/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 4 th started
# https://www.amazon.com/Dell-Inspiron-Desktop-Service-diagnosis/product-reviews/B07S3XD24T/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 5 th started
# https://www.amazon.com/iBUYPOWER-Computer-Element-9260-i7-9700F/product-reviews/B07V34QQ3C/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 6 th started
# https://www.amazon.com/Acer-Z24-890-UA91-i5-9400T-802-11ac-Wireless/product-reviews/B07R4PQJNM/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 7 th started
# https://www.amazon.com/Acer-C24-865-UA91-i5-8250U-802-11AC-Wireless/product-reviews/B07R5Q14HT/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 8 th started
# https://www.amazon.com/Dell-OptiPlex-Computer-Desktop-Windows/product-reviews/B07WT61X6R/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 9 th started
# https://www.amazon.com/Fanless-Celeron-Desktop-Computer-3xUSB3-0/product-reviews/B082VVGCPB/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 10 th started
# https://www.amazon.com/Philips-Computer-Monitors-328E9QJAB-Replacement/product-reviews/B07KQXJLF7/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 11 th started
# https://www.amazon.com/Acer-TC-885-UA91-Desktop-i3-9100-802-11AC/product-reviews/B07R8WK8VP/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 12 th started
# https://www.amazon.com/CyberpowerPC-Supreme-i7-9700K-GeForce-SLC8260A2/product-reviews/B07VFFCQ6L/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 13 th started
# https://www.amazon.com/Dell-Optiplex-Processor-Keyboard-Bluetooth/product-reviews/B07NBWF1ZP/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 14 th started
# https://www.amazon.com/HP-4NN56AA-ABA-Pavilion-24-Xa0032/product-reviews/B07SGH132Y/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 15 th started
# https://www.amazon.com/HP-8300-Elite-Computer-Quad-Core/product-reviews/B01CV9G1BO/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 16 th started
# https://www.amazon.com/Dell-Optiplex-7010-SFF-Desktop/product-reviews/B01HSDJFFM/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 17 th started
# https://www.amazon.com/Do-You-Trust-This-Computer/product-reviews/B07GD6L12X/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 18 th started
# https://www.amazon.com/Dell-Optiplex-Desktop-Business-Computer/product-reviews/B083JK71HD/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 19 th started
# https://www.amazon.com/SkyTech-Archangel-Gaming-Computer-Desktop/product-reviews/B0771BZY92/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 20 th started
# https://www.amazon.com/SkyTech-Version-Supremacy-Gaming-Computer/product-reviews/B07GP2H8WS/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 21 th started
# https://www.amazon.com/Quad-Core-A6-1450-Processor-1-0-1-4GHz-Ethernet/product-reviews/B083QGVFWL/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 22 th started
# https://www.amazon.com/HP-Pavilion-i5-9400F-Hexa-Core-Bluetooth/product-reviews/B082J6QPX6/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 23 th started
# https://www.amazon.com/HP-Elite-Desktop-Computer-Package/product-reviews/B07YF41Y6H/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 24 th started
# https://www.amazon.com/Dell-OptiPlex-Desktop-Complete-Computer/product-reviews/B00IOTZGOE/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 25 th started
# https://www.amazon.com/OPTIPLEX-390-DT-Bluetooth-Professional/product-reviews/B07DY47BQQ/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 26 th started
# https://www.amazon.com/HP-ProDesk-Business-Desktop-Computer/product-reviews/B07BCGW85X/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 27 th started
# https://www.amazon.com/Rain-Design-mStand-Laptop-Stand/product-reviews/B000OOYECC/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 28 th started
# https://www.amazon.com/Dell-Inspiron-Desktop-i3-8100-i3470-3903BLK-PUS/product-reviews/B07PPJQ5BP/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 29 th started
# https://www.amazon.com/Apple-ME086LL-Desktop-Mountain-Renewed/product-reviews/B00M4LWXI0/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 30 th started
# https://www.amazon.com/Fanless-Desktop-Computer-Windows-Mounting/product-reviews/B07QY8LDGX/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 31 th started
# https://www.amazon.com/HP-EliteDesk-800-G1-Business/product-reviews/B074S9BST6/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 32 th started
# https://www.amazon.com/Computer-History-Films-Sprocket-Flicks/product-reviews/B0798217HY/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 33 th started
# https://www.amazon.com/GL10DH-Desktop-GeForce-Windows-GL10DH-AH762/product-reviews/B07X1TZT85/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 34 th started
# https://www.amazon.com/HP-8100-Desktop-Computer-Package/product-reviews/B07SS5VQ34/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 35 th started
# https://www.amazon.com/Acer-SB220Q-inches-Ultra-Thin-Monitor/product-reviews/B07CVL2D2S/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 36 th started
# https://www.amazon.com/Bmax-Wideview-Computer-Speakers-Windows/product-reviews/B083HLLJNT/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 37 th started
# https://www.amazon.com/CYBERPOWERPC-Xtreme-Gaming-i5-9400F-GXiVR8020A6/product-reviews/B07N2BK6SM/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 38 th started
# https://www.amazon.com/HP-Stream-Dual-Core-Processor-Bluetooth/product-reviews/B07XJG81K4/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 39 th started
# https://www.amazon.com/Compaq-Pro-6305-SFF-10-Multi-Language/product-reviews/B07KJDBVN2/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 40 th started
# https://www.amazon.com/Dell-Optiplex-7010-Computer-Quad-Core/product-reviews/B077D4SFMF/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 41 th started
# https://www.amazon.com/Dell-Optiplex-990-Desktop-Computer/product-reviews/B07TW8QHZS/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 42 th started
# https://www.amazon.com/Dell-Optiplex-Business-Computer-Professional/product-reviews/B0725BFYV6/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 43 th started
# https://www.amazon.com/Algorithms-Live-Computer-Science-Decisions/product-reviews/B01D24NAL6/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 44 th started
# https://www.amazon.com/HP-Elite-8200-Ultra-Desktop/product-reviews/B0754MN7D3/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 45 th started
# https://www.amazon.com/Latest_DELL-Performance-Generation-Processor-Bluetooth/product-reviews/B07NJLQDN7/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 46 th started
# https://www.amazon.com/Optiplex-Desktop-Monitor-Windows-Renewed/product-reviews/B01LY0WLCT/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 47 th started
# https://www.amazon.com/SkyTech-Archangel-Gaming-Computer-Quad-Core/product-reviews/B077QDM2DP/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 48 th started
# https://www.amazon.com/HP-ProBook-x360-Touchscreen-Professional/product-reviews/B0836WQ9K9/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 49 th started
# https://www.amazon.com/Dell-Optiplex-990-Desktop-Computer/product-reviews/B01H63TWZC/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 50 th started
# https://www.amazon.com/Dell-Optiplex-7010-Desktop-Computer/product-reviews/B07RNMXDRF/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 51 th started
# https://www.amazon.com/Dell-Optiplex-7010-Business-Computer/product-reviews/B07SYC6HRK/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 52 th started
# https://www.amazon.com/Desktop-Quad-Core-Celeron-Processor-Pre-Installed/product-reviews/B07T2876DK/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 53 th started
# https://www.amazon.com/HP-VH240a-23-8-inch-Speakers-Landscape/product-reviews/B072M34RQC/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 54 th started
# https://www.amazon.com/32-0-Computer-Privacy-Screen-Filter/product-reviews/B07FK66JM5/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 55 th started
# https://www.amazon.com/Fanless-x5-Z8350-Graphics-Computer-Windows/product-reviews/B07D9YX3W6/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 56 th started
# https://www.amazon.com/Computers-Made-Easy-Dummy-Geek/product-reviews/1983154830/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 57 th started
# https://www.amazon.com/Vivobook-R5-3500U-Graphics-F512DA-EB55-SL-Transparent/product-reviews/B07S18PQNK/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 58 th started
# https://www.amazon.com/Acer-Display-i5-8265U-Fingerprint-A515-54-51DJ/product-reviews/B07RF2123Z/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 59 th started
# https://www.amazon.com/Gaming-Desktop-Computer-3-10GHz-Windows/product-reviews/B0845LJMZW/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 60 th started
# https://www.amazon.com/CHUWI-HeroBox-Windows-Expandable-1000Mbps/product-reviews/B082VZP76P/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 61 th started
# https://www.amazon.com/HP-Desktop-Computer-Processor-Included/product-reviews/B01LYF2TRL/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 62 th started
# https://www.amazon.com/Skytech-Shiva-Gaming-PC-Desktop/product-reviews/B07RPCG8ZW/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 63 th started
# https://www.amazon.com/Windows-Computer-Bluetooth-1000Mbps-Ethernet/product-reviews/B08313MYG6/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 64 th started
# https://www.amazon.com/A4-7210-Upgradeable-Computer-Bluetooth-2-5-Inch/product-reviews/B0834LS29D/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 65 th started
# https://www.amazon.com/Windows-x5-Z8350-Computer-Ethernet-2-5-Inch/product-reviews/B07TYLRPNP/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 66 th started
# https://www.amazon.com/Acer-K202HQL-viewable-Monitor-Ports/product-reviews/B00KWCD8D2/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 67 th started
# https://www.amazon.com/Dell-Inspiron-14-Computer-Quad-Core/product-reviews/B084M623DB/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 68 th started
# https://www.amazon.com/AWOW-Computer-8GB-256GB-Dual-Band/product-reviews/B0836RY5QD/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 69 th started
# https://www.amazon.com/Lenovo-E590-Business-Laptop-Professional/product-reviews/B07TD7N4WK/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 70 th started
# https://www.amazon.com/Skylarking-Anti-Glare-Protector-Compatible-Widescreen/product-reviews/B07NTK8CRD/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 71 th started
# https://www.amazon.com/NZXT-H510-CA-H510B-BR-Management-Water-Cooling/product-reviews/B07TC73F6Y/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 72 th started
# https://www.amazon.com/Ideacentre-520-24ARR-23-8-Inch-Computer-Antivirus/product-reviews/B083F7CCQV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 73 th started
# https://www.amazon.com/HP-Flagship-Pro-Bit-Multi-Language-English/product-reviews/B07L7P3XYW/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 74 th started
# https://www.amazon.com/Computer-Programming-Arduino-Intermediates-Language-ebook/product-reviews/B082P14Q8P/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 75 th started
# https://www.amazon.com/Lenovo-15-6-Inch-i5-8250U-Windows-81CA0008US/product-reviews/B0752W6W4Q/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 76 th started
# https://www.amazon.com/Mini-PC-AWOW-Computer-Bluetooth/product-reviews/B07XBKFZVL/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 77 th started
# https://www.amazon.com/Timetec-1333MHz-PC3-10600-Unbuffered-Non-ECC/product-reviews/B0145S5Z8O/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 78 th started
# https://www.amazon.com/HP-ProDesk-Desktop-Graphics-WIndows/product-reviews/B07V6W7JC8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 79 th started
# https://www.amazon.com/LG-32MA68HY-P-32-Inch-Monitor-Display/product-reviews/B01IA9FXAO/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 80 th started
# https://www.amazon.com/HP-2020-Touchscreen-Premium-Laptop/product-reviews/B083D72PK1/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 81 th started
# https://www.amazon.com/SkyTech-Blaze-Gaming-Computer-Desktop/product-reviews/B07RHBLV7F/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 82 th started
# https://www.amazon.com/Skytech-Archangel-Gaming-Computer-Desktop/product-reviews/B0825DRV8F/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 83 th started
# https://www.amazon.com/Dell-Inspiron-i3583-Touch-Screen-Laptop/product-reviews/B08173ZTJX/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 84 th started
# https://www.amazon.com/Dell-Optiplex-20-Inch-Monitor-Professional/product-reviews/B0176WQ792/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 85 th started
# https://www.amazon.com/Computer-Science-Distilled-Computational-Problems/product-reviews/0997316020/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 86 th started
# https://www.amazon.com/Timetec-1600MHz-PC3L-12800-Unbuffered-SODIMM/product-reviews/B0145WDNF2/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 87 th started
# https://www.amazon.com/Pentium-Windows-Upgradeable-Output-Support/product-reviews/B082VCCQ2B/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 88 th started
# https://www.amazon.com/Windows-Beelink-Processor-Supports-Ethernet/product-reviews/B082XGSCP2/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 89 th started
# https://www.amazon.com/HP-Pavilion-24-inch-Computer-24-xa0020/product-reviews/B07GRCDDX8?reviewerType=all_reviews&pageNumber=1
# There is review
# 90 th started
# https://www.amazon.com/COMPUTER-PROGRAMMING-Intermediate-Everything-Programming-ebook/product-reviews/B083QPQ9NR/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 91 th started
# https://www.amazon.com/MOSISO-Compatible-Repellent-Polyester-Protective/product-reviews/B083GJNH6S/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 92 th started
# https://www.amazon.com/Sceptre-E205W-16003R-Frameless-Speakers-Metallic/product-reviews/B07743412C/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 93 th started
# https://www.amazon.com/HP-Business-Computer-Ci5-4570-Wireless/product-reviews/B07XJQRMZF/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# There is review
# 94 th started
# https://www.amazon.com/MINIX-Fanless-Directly-Technology-Limited/product-reviews/B07MNLRJK9?reviewerType=all_reviews&pageNumber=1
# There is review
# 95 th started
# https://www.amazon.com/HP-Pavilion-Notebook-Computer-Bluetooth/product-reviews/B07T4LMCZX?reviewerType=all_reviews&pageNumber=1
# There is review
# 96 th started
# https://www.amazon.com/HP-800-Mini-Business-Desktop/product-reviews/B07SNGJSC5?reviewerType=all_reviews&pageNumber=1
# There is review
# 97 th started
# https://www.amazon.com/Computer-Compatible-HP-8100-Keyboard/product-reviews/B07SRW4P12?reviewerType=all_reviews&pageNumber=1
# There is review
# 98 th started
# https://www.amazon.com/TUMI-Voyageur-Mauren-Laptop-Computer/product-reviews/B081TPMR5R?reviewerType=all_reviews&pageNumber=1
# There is review
# 99 th started
# https://www.amazon.com/Dell-OptiPlex-Memory-WINDOWS-Renewed/product-reviews/B00NBRGQIE?reviewerType=all_reviews&pageNumber=1
# There is review
# 100 th started
# https://www.amazon.com/Computer-Speakers-Bluetooth-Microphone-Aux-Input/product-reviews/B07YDJGPCN?reviewerType=all_reviews&pageNumber=1
# There is review
# 101 th started
# https://www.amazon.com/Computer-Science-Principles-Foundational-Concepts-ebook/product-reviews/B081TK5NQ3?reviewerType=all_reviews&pageNumber=1
# There is review
# 102 th started
# https://www.amazon.com/Dell-Inspiron-i3668-Desktop-PC/product-reviews/B07BZVV4NH?reviewerType=all_reviews&pageNumber=1
# There is review
# 103 th started
# https://www.amazon.com/CYBERPOWERPC-Master-Gaming-GeForce-GMA8880CPG/product-reviews/B07PKXGC33?reviewerType=all_reviews&pageNumber=1
# There is review
# 104 th started
# https://www.amazon.com/Logitech-Desktop-Widescreen-Calling-Recording/product-reviews/B004FHO5Y6?reviewerType=all_reviews&pageNumber=1
# There is review
# 105 th started
# https://www.amazon.com/Computer-Networking-This-Beginners-Guide-ebook/product-reviews/B08381Z1H1?reviewerType=all_reviews&pageNumber=1
# There is review
# 106 th started
# https://www.amazon.com/ASURION-Desktop-Computer-Protection-350-399-99/product-reviews/B07PBD4P2L?reviewerType=all_reviews&pageNumber=1
# There is review

# %%
reviews
# Out:
# ['\nThe computer does not have WiFi capabilities as the title implies\n',
#  '\nComputer arrived packaged well. Very easy to set up, even for me who knows very little about computers. Wifi works no problem, so those that commented it didn\'t might have had bad luck. My only complaints after using the computer for a few days is that the keyboard is awful. Very cheap and not responsive to typing. also smaller than the one pictured so do not expect a full size keyboard (it is 4.5" by 16")  The speakers on the computer are not worth calling speakers. If you go with this purchase, plan in your budget to buy speakers and a keyboard separately.All in all it is a good computer for the money and the screen is very large.\n',
#  '\nThis is really a great value.  Looks and works like new.  Beautiful monitor, great  computer.  I love how compact it is instead of the old "towers".  Fits well in my small desk space.  Has wonderful features.\n',
#  "\nI tried to put the computer together and the monitor would not come on so I turned the monitor around and there was a connection that required a dvi cable.  So I ran to walmart and bought one only to find out that it would not connect to the computer.  So I ordered another dvi cable with a usb connection to the computer and have to wait two days for it to come.  In the meantime, I don't have a computer.  I don't even know if this thing is going to work.\n",
#  "\nIt was easy to set up. The base has some damage but nothing that effects the operation. Didn't come with instructions except for the Windows activation.\n",
#  "\nThis is the first time I bought a computer. I never even had a laptop. I bought it to do school work. But I was like what the hell let's get a game. And this stuff is awesome play game on. I love it and and boy was  super cheap it comes with the speaker in the motherboard but you might want to buy another one cuz it's not that loud.\n",
#  '\nI really debated on how many stars to give it. Yes, it was cheap. But still...probably 2.5 stars would have been more accurate. The computer did arrive more quickly than expected. That’s about the best thing I can say for it. There were problems from the start. Just getting it to boot up for the first time was a challenge. It would go so far and freeze. I’d leave it several minutes, but nothing short of the power button would work. After leaving it again and playing with it I was able to finally get it to boot up and go through set up. The mouse that came with it didn’t work, so I replaced it with a spare I had on hand. Once everything was set up I started taking a look at the software that was pre-installed. The first desktop icon I clicked on took a full 15 seconds to do anything. Internet Explorer, my preferred browser, wasn’t installed. I ate a leisurely lunch while it downloaded. Yes, it took that long. And before anyone asks, there is nothing wrong with my internet. I logged on to my Edward Jones account, but I didn’t have the patience to wait FOUR MINUTES between screens. There is software installed on the machine that I wasn’t expecting, such as Microsoft Publisher, Excel, and some second-class programs for opening pdf files, etc. Oddly, no Adobe Acrobat Reader. The machine is obviously used, which I knew when purchasing, but it feels like the previous owner’s data files were wiped out but their programs left in place. It’s not worth the hassle to return the computer, so I’m going to start stripping out the unwanted programs, give it a thorough going over to make sure there are no unwanted “gifts” on there, and see if I can’t get the speed up to at least close to where it should be. But this should serve as a caution to other buyers that they’re probably not going to receive a machine likely to work satisfactorily out of the box.UPDATE - One day later and the keyboard has quit working.\n',
#  "\nI rec'd desktop today.  I was a little weary ordering bc I just returned one that I bought thru Amazon from another vendor bc I could not get the Wifi to work and it was utterly impossible to connect with the vendor for help.  This computer turned on and the Wifi started right away.  The speakers are quite low (they are on the highest volume) but I still would recommend for the price and the fact that it does work.\n",
#  "\nGood value for the money as far as the monitor goes. i5 processor is kinda slow for today's web, so I kinda wish I went with something bigger. Still good value for the money. But the keyboard and mouse are horrible - they are branded United PC-Tech (same as merchant) and they aren't worth anything. On the keyboard is tall and the keys require lots of travel... and you must push the keys down all the way otherwise they won't react. It will drive you nuts if you are used to using a Surface or any laptop. The mouse... get this - it isn't level!! Who sells a mouse that isn't level!?? How do you even manufacture a non-level mouse? It wobbles back and forth like a chair with one leg too short. These components were obviously taken off of China's trash heap, the merchant probably got them free or for cents on the dollar because they are worth less than the bag and zip tie that came with them. All in all, value for the tower and monitor is good, but purchase a mouse and keyboard separate.\n",
#  '\nThis computer package is used for two church committees.Although you can see some wear and tare on the monitor, it works perfectly well and I am happy with my purchase.\n',
#  '\nI really like this stand!  It suits my 15" Macbook Pro perfectly.  Nice matching aluminum material.  Very solid.  Even with the clear shell I have on the Mac.  It keepa my mac safe above my bar surface.  Its almost worh getting as an insurance policy against spills.  I added a bluray drive and USB/card reader port to the underside... so it is more of a utility dock now.  Great setup!\n',
#  "\nNot only is this stand stylish (it seem like something Apple would make), but it is at a great height and incline for typing, and there is plenty of space underneath my laptop to store my external hard drive... the cat also likes to lay under there. :) I highly recommend this product.UPDATE (2-22-18): I'm still using and loving this stand, although the cat no longer fits under it so easily.\n",
#  "\nThis is a fantastic option for any Mac laptop user. I work from home and revamped my Macbook Pro into what now feels like a desktop. I no longer have to hunch down to look at the screen-- giving me better posture and less back/neck stiffness. You can't tell from the picture, but the forward facing part (where the computer would press against) also includes more of the rubber padding that you can see on the flat part of the stand. So, don't worry about any scuffs happening to your pretty aluminum Macbook Pro or Air. The color also matches completely, so it looks like it was created by Apple as well. I'm a picky person, but I literally have no complaints!\n",
#  '\nWhen the rubber bumpers on my stand fell off, I contacted Rain Design\'s customer service about it. Their response was, "unfortunately after time the pads do fall off" and then suggested I pay $6 to buy additional bumpers from them. The mstand is a premium product, costing twice that of the Amazon brand laptop stand. If the manufacturer knows that the bumpers will fall off, they should fix the adhesive that they use instead of expecting customers to continually pay them for new bumpers.\n',
#  "\nI had same problem as many others giving this product one star--the rubber strips designed to hold the laptop in place come off after a short time.  I came home once to find my laptop had fallen off the stand and onto the floor because the grips don't stay in place. By the way, I live alone and have no cat or dog, so no it wasn't knocked off by another person or a pet.  Do not buy this product if you value your laptop!\n",
#  '\nI saw many of the reviews who had used this with a 15" laptop, and wondered how well it would work with my 17" MBP.  I don\'t know anyone that owns one, so I was a little uncertain.  No worries - it works PERFECTLY!  See the image I loaded that shows it in use, along with a 22" Gateway monitor, and a 24" HP monitor that complete my workstation.The design leaves room underneath the unit, which is great for extra storage, or sliding a keyboard under (although it\'s not quite high enough if you tried to type under it).  Solid construction that should last, quite simply, forever.  The unit positions the laptop\'s screen to a height that works perfectly with my other external monitors.Interestingly enough, the packaging it came in even reminded me of how Apple would have packaged it.  It\'s a wonderful product that fills an obvious need, and is one of those "why didn\'t I think of that" items.  Simple design, beautiful, and very functional.\n',
#  '\nFantastic product! I bought this for my home recording studio so that I could have my 15" MacBook Pro behind my midi keyboard. This stand is a perfect match to my MacBook Pro and the quality is excellent. For me it was just the right height so that it clears my midi keyboard :)\n',
#  "\nBeware if you purchase a USED version of this stand. Arrived today but had a cheaper steel amazon brand stand inside the Rain design Mstand box. Someone was naughty on their return.... Very disappointed it wasn't picked up when it was restocked. This would've been my second Rain Design Brand stand since i was extremely happy with the first one i bought a few months ago. Would've rated it 5 stars if correct stand was inside. Hopefully this will now be figured out in returns so it doesn't happen to someone else.\n",
#  '\nAt first I was skeptical about the purchase, since it\'s not necessarily cheap, and many would say a couple of old thick books would get the job done.I do a lot of video and photo editing which means I can spend 5+ hours a day on my laptop. I became cautious about the health impacts of doing this, certainly the damage it does to your posture and consequently how you walk afterwards.The mStand elevates the screen to a much better height for day to day viewing where you don\'t have to bend your neck to look down at your screen. The screen is still slightly below eye level for myself (6\'4") however works completely fine.Yes, a couple of thick books will also raise your screen, however I\'d much rather spend $40 on something that looks extremely elegant and is identical in design to my MacBook Pro. Furthermore I can stow my bluetooth keyboard under the stand.Build quality is 9/10, very well built, looks elegant however when you type on your laptop it is prone to slight bounce/flex which is understandable since they wanted to keep the weight as low as possible.I highly recommend this product, I even brought it with me abroad as I moved somewhere else.\n',
#  '\nThis was a product I wasn’t originally sold on but after owning it for almost a year, and adding a wireless keyboard & mouse. I can’t imagine using my laptop (MacBook Pro 13inch) for extended periods without it.THE GOODThe mStand’s design is sleek and minimalist, this is why I chose it over similar products. The style I purchased doesn’t have the rotating swivel base. I didn’t want to accidently have it spinning whenever I repositioned the stand, and that functionality wasn’t that attractive to me but I may give it a try in the future.I’d recommend using the stand with a wired/wireless mouse & keyboard, as this will greatly enhance your experience.However, if you have to use the keyboard and trackpad while your laptop is on the stand, there’s very little bounce as you press down on the keyboard. The laptop feels secure and the stand doesn’t move around, I’m not sure if this is the same for the rotating swivel base version. Another thing, your arms do start to tire out if you continue using your laptop this way, at least they did for me.THE BADThe price is a bit on the high end. If you’re on a budget, you can purchase something like the AmazonBasics version for a lot less. Same functionality but it may look and feel cheaper. I went with the mStand because different sources gave it a high praise and I liked the design. Also, if you’re like me, and you’re planning on owning this stand for a long time, might as well get a high quality one. And this is definitely a high quality one.Even though the stand is padded to protect your laptop from scratches. If you’re not careful as you’re placing the laptop on the stand, there are some areas where metal on metal can definitely lead to a scratch. It hasn’t happened to me but it’s something to be aware of.THINGS TO NOTEI mainly used the stand while doing some Adobe Indesign work, R programming & data analysis, putting together slide decks, and general internet use.One last thing, a common sense sort of thing, how far you position the stand from you will impact the strain on your eyes. As a person who wears glasses, I have to have the stand a bit closer towards me so that I can still read and not be overly fatigued. But whenever I’m using it to watch videos, I’ll move the stand further back.It also does take up some space so make sure your desk has enough room for it. The area underneath the stand serves as a nifty storage space, I use it to put away my wireless keyboard.All in all, I’m super happy with this purchase. So much that I’ve bought it twice. And I’ll continue supporting this company for many years.Cheers!\n',
#  "\nI am a at home mom with a small online business. I don't have money to waste so I researched many sites for about 4 days trying to make sure my purchase was worth it.. I CRIED TEARS OF JOY after receiving my COMPUTER😭🙌🏾. I feel like this company understands the value of a dollar because it showed through the careful packaging and the condition of the computer shows little to no sign of wear and tear.Monitor, Hard drive, Keyboard and mouse all cords was included.The Keyboard and mouse is BRAND NEW🙌🏾.Shipment arrived about 2 days after ordering..Connecting this Pc to my wifi, printer and began to search the web was completed with 15 minutes.Fast with No delays in website searching, that was a big concern for me too.I am so thankful I picked this company.\n",
#  '\nWow!  I had ordered refurbished computers off amazon before and they were such disasters i swore i would never do it again!  However, i did it again, and wow!  This company is great!  Looks brand new, just a little scuff here and there, set up was easy, quick and painless, and everything is working like a dream!  Forget those other rebuild companies and go with Blair!\n',
#  '\nThe computer works well, it was received in Afghanistan and set up was easy.  Computer operates as designed and has good software in it.  For $200 this was what I needed when I needed.  However the company does not ship to APO overseas. The monitor and picture are good quality and I like the machine,  Saved me $300 in having to buy a new Dell desk top computer.\n',
#  "\nI wanted a new desktop to replace an old, burnt out Desktop Clone with Windows XP I've had since 2003. Yes, it still worked until last year. I didn't want to spend a great deal of money, especially with Windows 10, ad OS I strongly dislike. This package was very appealing: what it contained and the price. I've only had it a couple of days, but so far, so good. Everything in it works as should. Everything arrived as described and promptly. Packaged was well packaged, though, why it isn't marked fragile, I don't know. No assembly instructions were included, but it was very easy to install. I don't know about the quality of keyboard and mouse because I'm using my older one. Very easy to connect to WiFI. No issues have arisen yet. I hope this one lasts half as long as its predecessor. It's fast, too, though I don't know about gaming. It comes pre-installed with licensed Windows 10  Pro, which in comparison only has one feature not in Windows 10 home, so not worth much at all. I did some research online about this model. It's from 2011 and went for $1599.00 at that time with an overall score of 4.25 out of 5 stars in satisfaction. Of course, with full refurbishment here, it has been built up and upgraded. The package comes with a major brand monitor, but you don't know which one until you receive it. I received a Lenovo Thinkpad with mine. Overall, I think it is a good purchase at a great price.\n",
#  '\nThis computer was a Christmas gift for my son. What a disappointment!  The mouse was broken into pieces, the monitor is dell brand but the tower is an hp brand? Not sure what that is about. The keyboard is so cheaply made that some the keys were popped off when I opened the computer.  My son was very sad and also disappointed with his gift.  I will never again purchase from this company. I am returning this piece of junk tomorrow once the stores are open and purchasing from a different company. If I could give zero stars, I would have.\n',
#  "\nThus far, I am completely satisfied with the function and capabilities of this computer. Needs computer speakers to increase volume and that's it.\n",
#  "\nI've only had it for a day or two now but for how inexpensive it is, it's AMAZING! I don't understand why anyone would rate this below 5 stars. This is not a $800 computer but it acts and looks like a $500 computer. I was hesitant to buy it at first when I saw how cheap it was, not knowing if in shipping it would get damaged, etc. but, it was completely covered in bubble wrap to protect everything! I know I haven't had it for long, but you can tell immediately that it is going to last. I plan on using it for school purposes only so on the gaming angle I'm not to sure how well this would work, but again, for the money it is 100% worth it.\n",
#  '\nExactly as described!! Clean unit, set up was quick and easy!\n',
#  '\nI liked it all\n',
#  '\nBeen using this for about a week now.  Nice professional packing inside the box. Included mouse and keyboard were cheap, but I had spare a spare Logitech setup that plugged right in.Make sure you read the card (both sides) that comes in the box so you can activate your copy of Windows 10 Pro. Added some speakers, a webcam, and a few programs, and I am setup to start my own YouTube channel!\n',
#  "\nI bought this to build a little emulating machine that I could carry with me and this thing had a decent price and a good amount of ports. My use-case is a little bit different from other people, but I can talk about some of the things that I've noticed using this so far.-Pros-1. The device comes with a legit copy of windows (mine had Windows 10 home). The box says 8 pro, but the inside says Windows 10. They probably updated the machine after it was made.2. The device makes zero noise and the unit itself doesn't seem to get that hot even with a ton of stuff open.3. Tons of ports: micro usb, usb 2.0, usb 1.0, sd card reader, ethernet, and hdmi.4. Very light. I can throw this in the bag and it doesn't add a lot of space or weight to my bag.5. Decent processor, which seems to be able to handle video streaming fine, although you'll probably need to use a wired connection for higher playback quality.6. Reliable Bluetooth connection7. Great performance with the gpu for retro gamesCons1. Wifi is a little dated, so you won't be able to connect to 5.0ghz signals. You're better off connecting this to lan which is what I ended up doing.2. Small storage: you'll be left with 15gb after you finish setup. This wasn't a problem for me because my roms are on a micro sd card, but I wanted to mention it here.\n",
#  '\nNote: This is a W8 Pro , There is no such thing as a T8 (just look at ACEPC website)I was able to remove windows and install Debian Linux  without any issues.I now have a very fast Mini PC server for development.make sure your bootable USB stick is installed before going into BIOS,otherwise it will not see the drive.\n',
#  "\nI have nothing but good things to say about this pc.- Small, size of 2 playing card packs side by side.- Quiet, I don't hear it at all.Has fast boot up time (10-15 seconds) and has the power to do anything but game.We use it for word, internet, music, but especially streaming.This PC handles any kind of streaming you want, biggest limiter for my family is the internet speed we have.The only downside I would say is the limited harddrive.If your looking for a small, quiet streaming box that can also do word/internet this is the perfect PC\n",
#  "\nFirst off, this isn't a gaming computer. If you expect this to act like an 800 dollar PC, you're going to be disappointed.That being said, it works extremely well for what it is.I had no issues out of the box aside from it being a tad slow. Once all of the updates were downloaded and applied and Windows was cleaned of its initial bloat, the system saw a significant speed increase. It performs well with web browsing and general operating system tasks and doesn't delay much when opening programs or asking Windows to perform tasks.It does only have 32GB of hard drive space, so you'll need to make sure you clean up the disk space after all of the Windows Updates (Windows is notorious for not cleaning up after itself). I also went through and disabled some of the un-needed services to free up resources.Even with the system getting hammered with installing updates and such, the little box remains relatively cool (it's still warm, but nothing outrageous).I had no issues playing 1080p mkv files or mp4 files as well as 1080p content from Twitch and Youtube. 4K video was hit or miss, so I'm not quite sure it's powerful enough for 4K.All in all, it's a nice little machine and it will suit my need perfectly as a little computer to hook to my projector as a portable movie computer.\n",
#  "\n\xa0I love this mini PC, it absolutely meets my expectation for a nice usable mini PC at affordable price.It is tiny,light weight and portable, about the palm size, doesn't take any space on the desk, easy to store or carry around.It comes with all the accessories to connect to the TV/Monitor, wired network or Wi-Fi, has USB 2.0, USB 3.0 and microSD slot for the expansion. Even though it has soft-keyboard that you can use, but I would highly suggest to get keyboard & mouse for the easy maneuver.It comes with Windows 10 Pro OS build-in, easy to setup and configure. For the price, of course you know it is not good fit to play video games. But it is fast and powerful enough to surf the web, check the email, watch the stream video,etc. It is excellent entry-level pc, good for kids or first timer computer users.Overall I am very happy with this mini-PC and highly recommend it.\n",
#  '\nMy home has a traditional TV in my living room. I really can not choose what I want to watch. I can not use to listen the music and watch YouTube video. After I bought this Window box, it makes my old TV  transfer to a nice smart TV. It comes with a Window box, Power cable and HDMI cable. The windows box has 2GB RAM and 32GB storage which can upgrade to 128GB. The 4K resolution gives very clear video. The Ethernet port on the window box will provide more faster internet speed than wireless Wi-Fi. The two USB port can connect with keyboard, mouse  or external storage as well. Now I have another "computer" in home, which can watch TV, YouTube Video, search Internet, listen music. It makes my life much easier. Kindly reminder, this is not window box for gaming !\n',
#  "\nI bought this mini pc for couple reasons and found my expectations are met.If I need a lot of memory or very fast processor then I wont need this, and probably buy a i3 instead.The main reasons are:* mini size.  Very portable, it's just slightly greater than a cup coaster,  it can be fit in a jacket pocket without problem.  And most of the hotels around are now equipped with HDTV that has hdmi input, so you can hook it up easily with your travel.* of course Windows friendly.  It is installed with windows 10 home.  The version I found out on mine is 1709.  So the familiar windows apps can still be run on this mini pc.* adequate and power enough for most use.  Streaming and watch videos I found no problem.  Office applications are ok.  Internet browsing is also fast enough and responsive.  Of course dont expect you can open 20 tabs.  I'm surprised with its performance even it has only 2gb ram.* usb 3.0 port.  I am happy it comes with built in wifi and a usb 3.0 port.  The internal flash storage is ok, not fast like the ssd nor harddrive.  So the usb 3.0 port comes in handy to expand storage and maybe it can used to connect some drives and use this mini pc to server as mini file server.Box runs little warm but not hot.  Satisfied with this mini windows box overall.  Price is ok for me while it's still under 100 and have windows installed.  It is activated with no problem.\n",
#  "\nI am using this to run a picture frame.  I have had it running for several weeks now.  It does what I wanted it to.  I have it set up to run a slide show in a 4x3 part of the screen and the time, calendar, and current and forecasted weather in the other part.  On a side note I don't like how some of the larger WiFi picture frames are 16x9 when pictures are still shot 4x3.  I have it configured to allow me to upload pictures to it via WiFi.  I am using a free program that allows me to do this from anywhere.\n",
#  '\nIf I give 5 stars, I guarantee you won\'t read this review. I intent to use it as web server. I installed it with Ubuntu 18.10. Everything was just excellently fine except the battery management daemon. The power level kept on decreasing continuously although there is no battery inside. Initially, I suspect it was Ubuntu bug. But after a few hours of Google search, I decided it could be hardware wiring problem. Hardware wiring of power supply may trigger Ubuntu to think it was battery instead of a power supply. Therefore, I had made the following changes to the following file:"/etc/UPower/UPower.conf".....NoPollBatteries=true.....PercentageLow=-100000PercentageCritical=-30000PercentageAction=-20000.......Then reboot my machine. Fortunately, the machine didn\'t send battery updates to UPower of Ubuntu 18.10. The battery level stopped at 60.0% finally. Thanks God that I fixed it. I can never let a server shutdown every 15 hours.I am still testing this machine with MySQL/java 11/tomcat 9 installed.Besides, I happened to have a Bluetooth keyboard with external USB Bluetooth receiver. It works with bios booting. I can control the boot sequence to include external bootable usb for Ubuntu 18.10 installation.Amazing that I don\'t have to buy a usb keyboard.I didn\'t remove Windows 10 yet. But I will remove it after my web server test.\n',
#  '\nA friend recommended it to me and I purchased this last week ,overall it is a great buy. 2GB+32GB So surprised to see such small device supports dual screen display. I install a 2TB HDD and it works great ,the whole installation is simple ,no need to search for the technical knowledges .\n',
#  "\nI purchased this desktop computer for a work from home gig with Arise and I have no issue with it at all. Obviously it's not going to run as fast as a newer model but it isn't as slow as a turtle either. It does tend to stall when downloading something or when I switch between software programs like Microsoft Word to Excel but it's not long enough to get on my nerves.I truly am amazed with this purchased, it meets my expectations and I'm happy I purchased from this seller. I have to admit that I was skeptical but I did not want to spend over $500 for the newer models especially since I mostly use my Macbook.Again, this computer is for work and I am satisfied with it!!\n",
#  '\nI needed a computer that would work for an at home job.  I did not want to spend a lot of money on it because it was for work only.  And I must tell you so far so good! I have to say thank you.  I got my pc and I was so impressed.  it was packaged very well  It also came with informational inserts on what to expect.  Also came preloaded with a couple of software,  even though there may be an additional charge to use them.  I saved me the time search.  But my all time favorite is BTG software just incase had any problems it was right there at my finger tips.  I feel like my money was well spent.  Thanks guys!\n',
#  '\nProduct arrived with minimal protective packaging. The PC unit was free to bounce around in an empty space 2x larger than the unit itself, without so much as a sheet of bubble wrap. The box containing the monitor/cords/keyboard was sealed with packaging tape that appeared to have been reused, as it would hardly stick to the box.I unpacked everything and connected the components according to the single sheet of instructions that was included. I turned on the monitor and pressed the power button on the PC. Immediately, a red light on the front of the PC began flashing and a repeating series of 3 beeps began to sound. Not good. Nothing appeared on the monitor. The button to open the DVD drive tray also did not work.In short, the PC did not work. At all.Upon reviewing the included information sheet, it stated that no exchanges or returns would be done without contacting their technical support. I went to the website listed, only to find the support section “under maintenance”.So I’m currently trying to return this item through Amazon. I fully expect my request for return to either be denied or not replied to at all, in which case I’ll file a claim.I didn’t expect much of a computer for $133. This was supposed to be a Christmas gift for my elderly mother in law, and all she needed it to do was browse the web. But this was so shabbily packaged, it honestly feels like a scam.I just hope I’m able to get my money back.\n',
#  '\nThis will be THE best 159.00 you will EVER spend , when you take this computer out of the well packaged box and set it up , you’ll think it’s brand new !!  I would recommend this as a 2nd computer to set up in a guest room ect .  .. does everything we need it to do as a basic computer ..  highly recommend buying ..  shipping was faster then expected too.\n',
#  "\nI ordered this computer bc my other computer was damaged during my relocating/move and was stoked to receive my new/refurbished computer and it will not work for anything! For 5 hours now it has told me it's fixing disc errors. What disc?! I just dont get it. Do not advertise that a product works if it diesnt! I work from home and have no way to log into work tonight!\n",
#  "\nOk......I must admit that I was a little worried at first, but after I got it hooked up, I was thrilled. For the price that was paid, it was an awesome deal. I usually don't mess with refurbished products but figured I would take a chance and it was a great choice. I bought this for my son to do his work for homeschool and he loves it. It wasn't in perfect condition but it was better than fair. The delivery was extremely fast and I've heard many complain about the speed of the computer, but mine is actually quite fast.  All in all, I'm very satisfied with the product and have no complaints.\n",
#  "\nMy mother's PC got Fried by lightning. We went to look at one and it was over $400. I saved her a ton of money and she really likes it. She is 78 years old and uses it daily.\n",
#  "\nRight size, right speed, monitor picture better than expected at a great price!We need a computer, but we're not gamers.  We use it to research information and to stay in touch with friends, family and the world we live in.  Also use for paperless billings and health info.  Don't follow computer acronyms & new products, so when searching it was scary - kept wondering if we were going to get the next version up from a floppy drive - ha, ha!  Checked out seller before purchase - they stand behind their products - fantastic.  Well packaged, plain BIG box.  Did not have to contact with any questions!  All works perfect - yay!  Thank you!\n",
#  '\n\xa0At first I received the wrong CPU processor, however tech support for refurbished computer was exceptional in correcting this minor issue. I purchased this computer to work from home and now that I have the correct CPU I am highly satisfied and recommend this computer to anyone looking to use this for personal use or gaming. Everything I received was well packaged. Nothing was damaged. There were scratches on the back of the computer screen so you can tell it was used. The mouse appeared to be new. The keyboard appeared to be new but was probably used due to the space bar key having a little piece sticking out. It works just fine though. I’m completely satisfied with my purchase and prompt customer service/ support.\n',
#  '\nDon\'t waste your money. I\'m not picky, I just needed a computer for my kids to type school work and get on the internet.  This has been one hassle after another. The wifi adapter wasn\'t included, the seller did send a replacement, took 8 days to get. Mouse included had a 10" cord... couldn\'t reach to plug in, so bought a new wireless mouse. Windows keeps giving me a notification that the Windows 10 key I have is stolen or not valid... emailed seller again,  no response. I gues I\'m shelling out to activate windows too when it was supposed to be included.  This is not a plug-n-play set up. Very aggravating.\n',
#  '\nIt’s a good computer, but Microsoft is up to each usual tricks. It tries to get you to put a credit card in for Microsoft office before the 30 day free trial. This is a real pain when you already have a educational version of Microsoft and don’t use the 16 digit key. I eventually had to use Alt+F4 to close down the screen so I could uninstall Microsoft office in order to reinstall my educational version.\n',
#  "\nIt is the best option amongst those laptops at the same price. I'm really convinced by its efficiency. However, the design is unsatisfactory to me but that is not the important factor when considering purchasing this laptop.\n",
#  '\nIt’s very good laptop i buy it for my son he need it for his school work .\n',
#  '\nThis laptop is perfect.  Long battery life, sleek design and super fast.\n',
#  '\nGot the 14 inch, model 81C90009US and been using since end Jan 2018.  This is a super high value laptop, in that you get a ton of capability and expandability for your money while being able to run all the latest generations of hardware: 8th gen Intel i5 with 4 DISCREET cores plus hyperthreading, DDR 4 RAM, and PCIe M.2 SSD.  Did tons of research, bought and returned two other models before settling on the Flex5.My situation is that I recently retired so had to give up my work laptops and get something personal.  Have been a table PC user since 2004, so tablet PC form factor and functionality were a requirement.  While I could afford a pretty wide range of laptops, other requirements guided me to the Flex 5, specifically, touch screen, good active digitizer, the 14" size, and the PCIe M.2 + 2.5"SSD storage options all combined with an 8th gen Intel processor.  This COMBINATION of features and FLEXIBILITY is very hard to find, Lenovo really nailed it with the Flex5 at an outstanding price!Quick list of the Positives and Negatives, then more details and benchmarks below...Positives:+Tablet PC form factor (standard laptop, tent, tablet with touch and pen) with far above average performance and upgrade flexibility for the price.+Both PCIe M.2 and SATA SSD slots mean you can put a ton of very fast storage in this relatively compact machine.+8th gen Intel Core i5-8250U provides 8 total threads of processing on 4 physical cores plus hyperthreading, a very low base clock of 1.6 GHz for power saving, a 3.4 GHz Turbo for power when needed, and a nice low 15w total power dissipation for both battery life and running cool.  My experience is that some generations of Intel procs are smaller steps, some bigger, and the 8th gen is one of the bigger steps in speed and efficiency.+Great battery life, I regularly get 5-6 hours, more than enough for my usage style, and very good overall for all the power on tap, display size, etc.+14" screen is the optimum size for me personally.  I\'ve owned everything from 10"-17" laptops, and 14" is the sweet spot for me.  This screen is HD resolution of 1920x1080, which is fine for my use on the road or away from the desk.  I\'ve had a QHD external monitor, and that is fun, and where I\'d put my money if I needed more resolution.  I dock and have three HD screens, though, so that\'s enough for me.+Touch is extremely reliable and configurable.  Digitizer for the pen is Wacom, so it is OUTSTANDING for note taking, a key requirement for me.  The Lenovo Active Pen that comes with this config of the Flex5 is actually very good.  I\'ve got a drawer with about 30 different active and passive styli I\'ve used over the years, and this is one of the better ones.  It\'s also a good value at twenty six bucks.  I bought three extras, one for each of my travel cases plus the one in the holder that slides into the usb port on the Flex.\xa0Lenovo Active Capacity Pens for Touchscreen Laptop for Lenovo  Yoga 720, Flex 5, Miix 720, Miix 510 and Yoga 900s Laptops - GX80K32882.+Just enough ports.  With three USB3 on hand, two type A and one type C, I can do most of what I want and need directly connecting to the laptop when away from the desk.  See docking details under Connections, below.  The HDMI port is FULL SIZE, thank goodness, simplifying connections on the road, and the SDXC slot is also full size, meaning easier connections to all  that SDXC storage I have from multiple generations of cameras, etc.+802.11AC wifi built in.  My home is all multi channel AC, so this is nice from a speed stand point.+Expandable RAM.  I replaced the 8GB stick with 16GB Crucial\xa0Crucial ME CT16G4SFD8266 16G DDR4 2666MT s CL19 DR x8 Unbuffered SODIMM Retail, provides a nice bit of RAM headroom when using demanding programs or many programs.+Finger print reader is fast, reliable, and works extremely well with Windows 10.+Backlit keyboard is a real boon in low/no light.Negatives-The screen is just barely bright enough to use in a sunlit roo ...
#  "\nI've been pleasantly surprised by how much I like this laptop.  I've been using it for a month, and really enjoy its features.PROS1) My first touch screen laptop.  I am surprised how much I use the screen.  It is faster than a mouse, although I still use both.  It's great.2) Fingerprint reader - I love how quick I can unlock my computer using the fingerprint reader.  Also, it works with my password manager, Dashlane.  Saves time.3) Tent and tablet mode - I wasn't sure that I'd ever use these modes, but it turns out to be handy.  In tablet mode, I found it very convenient during Amazon's Prime Day sales.  It has a larger screen than most tablets, and perfect for the Prime Day sales.  I use tent mode to watch movies a little closer.  The speakers are positioned in such a way that I can hear things clearly whichever way it is set up.4) Pen - Well, I'm not yet fully sold on the usefulness of the pen.  Maybe if I liked taking notes by hand or drawing more.  Still, it's a nice feature to have.5) Solid State Drive - now whirling parts on the inside, and it is cooler to run.6) Fast, at least so far after one month of heavy use.  I'm avoiding downloading too many programs though.7) Speakers are louder and better quality than any of my previous laptops.CONS1) Two normal USB ports, and one USB C port.  Since most of my components use regular USB, I had to buy a special adapter to use the USB C port.  Still, three ports isn't enough, and the Lenovo pen holder uses one of the ports for stowing.2) Small Hard Drive - with only about 250 GBs of drive space, I can no longer store the amount of photos, movies, etc. that I did on my last computer.  No matter, I have a few external drives with several terabytes, but I wish my laptop had more space.3) No DVD drive - But like my hard drive, I have an external DVD drive that I got for around $20.In short, I really like this laptop and would probably buy a Lenovo again when this one eventually goes kaput.  Hopefully not for many years.\n",
#  "\nA little heavy for my preference.  It does have  a bigger screen, so it makes up for it.Also, it seems like is large enough to have a ten key, but they didn't include it.Everything else about this computer is awesome.  It's fast and very comfortable to type on and runs programs without issues.  Not too much bloatware either.I'd recommend it.\n",
#  '\nThis is now my every day at home use computer. The only problem that I have is the hinge is still a bit stiff, I think this will fix itself over time.I am very happy I picked this Lap T op.\n',
#  '\nI use this for work.  It retains the battery life pretty well - 8 hours or so working on it all day.I got the pen to go with it.The keyboard allows me to adjust the volume and screen brightness.\n',
#  "\nGreat laptop for the price, SSD is fast, plenty of RAM and processing power for normal use. I've done a bit of CAD and programming on it and it works great. Anything super intensive would need a more powerful computer but this laptop is great if you don't need it to be a full fledged work station. Screen is good except for the glare. Build quality is great.\n",
#  "\nI love the trackpad, super silcky. Love the keyboard. The keyboard has good depth and feedback, and the layout is what I'm used to on my desktop.The screen is too reflective. It is fine in low light and when there is a white background (which there typically is in most apps). I do use the laptop outside, so it is usable, there are just times when the reflection is too apparent, and interferes with seeing the screen.It looks very sleek and feels very solid. When I sit in certain positions with the laptop on my lap (go figure), the edges cut into my hands or wrists uncomfortably. It doesn't happen often, but it seems very unnecessary to be so sharp.The performance is great. I have 25 tabs open right now with no problem and only 8GB of memory.\n",
#  "\nI set up the finger print login and didn't note my typed password. Shortly after a required major system upgrade, the finger print login was erased and not remembering my typed password, I ended having to reset the laptop. Took me a week of research and trial and error before I was able to login. Then I found this upgrade had locked screen brightness at full. I don't recall how I got around that but it took about a week again of research. Everything else is so far fine but I didn't realize I was purchasing major hassles after these upgrades.\n",
#  '\nSSD provides fast start up with quick processing. Perfect for a young student doing homework, streaming media, web browsing. Thin, light and attractive.  Doesn\'t scream "budget" like some comparable laptops. Been great so far for my high schooler.\n',
#  "\nI bought Lenovo flex 5 on April 2, 2018 and after 5 months the screen started flickering which is very annoying. I don't know what to do and feel a waste of my money. I'm going to try to get this returned to the manufacturer if I could. I've been making it work despite of the flickering the moment I get on this. It looks like hardware issue but I'm not going to mess around with this issue.\n",
#  '\nI had to wait for a very long time to receive the computer system i ordered. When i finally got it ( about 20 days later), i wad shocked by what i received.Even though on the website they say the product " is tested and certified to look and work like new", what i received was extremely worn out dell tower and hp monitor, with scratches, dust, and stains all over. It looked like something taken out of a landfill!Now i\'m forced to buy another computer.\n',
#  '\nThis product arrived with a defective motherboard.  It was returned and repaired.  The seller then sent it out again.  About 70 days later, (reported 89 days after receipt)  and within the warranty period, it failed a second time—either the hard drive or the cooling fan bearing started an unholy whine.  The seller was havin none of it and utterly disclaimed responsibility.This was a violation of the express terms of the “warranty” not to mention the Beverly Song Act.  The dispute over what has turned out to be just a piece of electronic waste continues.\n',
#  "\nThis is a great little setup.For the price you do get a lot.I did upgrade the processor to a quadAnd added a graphics card since this computer didn't have one.I recommend the GeForce GT710\n",
#  "\nOK so I wanted to wait a while before I gave this a review ,  i've had this and been using it for a little over a month and I've had zero problems it doesn't even look worn or used and has tons of memory to hold the stuff I needed to, we use it for homeschooling personal use storing pictures things like that  I was really happy with the product and so far have been happy still if anything happens or goes wrong I will of course update their review ! The price on this was amazing and I couldn't be happier\n",
#  "\nI might never buy new again! You get a fast and more durable machine for $250. In my book that's an incredible deal!\n",
#  "\nSo far, several months, everything is working as anticipated. So at this point, I have to say this looks like a real bargain. The only things I would comment to the downside on are these. It was not exactly clear if the package included wif adapter, not say one way or the other was confusing, so when the unit arrived, I had go out and buy one. Another was that, although it comes loaded with Windows 10 Pro which is great, the next week was spent enduring frequent slow periods over the wifi not know why. Later, it became appartent that the version of Windows which came in the package needed considerable updating, which Microsoft supplied at no cost. But the way Microsoft did it was by opening sockets, in the background thereby sucking up bandwidth, without specifically providing notifications. Consequently, this causes me to spend a number of days troubleshooting with the vendor of my newly installed wifi adapter to see if that was causing the issue, and time with my ISP for the same reason. The issue finally became apparent when my son fired up his notebook and an none of the problems I was having, which meant it was not a speed issue with my wifi adapter, nor ISP. So that left my new computer which I was was about to contact the vendor about and return if necessary. But fortunately, as I have said the coz became apparent and since then no issues at all. IMHO, this could all have been avoided by including a more updated version of Windows 10 in the package. That way all or most of the time updating would have been done before I received the package. I wouldn't call these issues showstoppers and would and have recommended this package to anyone.\n",
#  "\nThis is a great machine. Worked perfectly out of the box. It's lightning fast and well worth the money. I'll definitely buy from JSM Computers again. Great products and great customer service!\n",
#  '\nFantastic value for business. Came with Windows 10 and MS Office Suite. No WiFi, only ethernet, but remedied with plugin USB WiFi receiver for $15.\n',
#  '\nThis product was listed as in good condition - it was very worn and the usb, monitor and cable ports in the back were very loose.The product looked better when I returned it than when it was received.\n',
#  '\nSeems to work as it should. I just need basic computer for household tasks and this fills the bill.Added surprise it came with a wifi adapter that plugs into a USB port also the key board and mouse were brand new in seals cartons\n',
#  '\nThe computer was set up and running in minutes. Absolute breeze to do that!! The 23 in. touch Screen monitor is amazing. Keyboard and mouse are cheap and flimsy, and were replaced within hours. The speed of the computer is good, except I failed to notice before buying this particular machine that the Hard drive is running at 5400RPM. So unless I convert to s SSD or replace the hard drive, the computer will never be a "Speed Demon." Even with a 3.25mhz processor.\n',
#  '\nI use it for many things, surfing, watching movies, excellent picture quality, love the touchscreen . Very quick setup, took about 30 minutes to be up and going, love the tilting screen also. The wide screen monitor makes watching movies or streaming videos a great experience.\n',
#  "\nHome office use, lite gaming  down loads. This is the 4th all in one i've purchased in the last 7 years, most used for work  the home one failed so got replaced with this I did up grade the ram to 16.Good machine.\n",
#  '\nI wanted to wait a while before I posted the review for this item.  Our family has really enjoyed this computer.  It’s easy to navigate and has everything we need for a family computer.\n',
#  '\nPurchased to replace a HP Pavilion with 27 inch screen. Had to get used to a smaller monitor and looking at it sitting vertically vs a 45% angle. Great sound and color. Really enjoy the pop up camera.\n',
#  '\nLove this computer! Easy set up right out of the box! Beautiful colors and resolution! This was my upgrade to Windows 10. My last computer was also an HP Pavilion All-In-One. It was running Windows 7. After 10 years it was still great but it was time to upgrade. Very pleased!\n',
#  '\nthe all-in-one so far is great, only complaint is the wireless keyboard & mouse use same USB; keyboard nice, the mouse is terrible, REALLY cheap!\n',
#  '\nI love HP products\n',
#  "\nCards on the table -- We are not power users or a gamers. We use the computer for web surfing, writing, and watching videos, and there's someone using the computer pretty much all day long. For the past several years, we've been using a variety of laptops and haven't used a desktop since they used clunky CPUs and boxy monitors and a boatload of cables. I am very impressed with the HP Pavilion desktop. The guts are all in the back of the monitor, which at 23.8 inches is huge. The included wireless keyboard and mouse are super simple to connect and require AAA batteries, included. That's it for hardware. The computer was a snap to set up, the most time consuming bit was importing my bookmarks to the browser, which if I had uploaded to the cloud in the first place, would have taken less time. Windows 10 is pre-loaded. The monitor is impressively sharp and it's a touch screen. I like the fact that the camera is in a separate slide-up attachment on the back of the screen, so when you aren't using it, it's completely hidden. I was a little doubtful about switching to a desktop after downsizing to a laptop, but this desktop takes up only a little more room and it's only because the monitor is bigger, which is turning out to be a real benefit, much easier to see the detail on maps, charts, photos, newspapers, etc. Writing is also easier with the keyboard detached -- you can put it where its more comfortable and angle the monitor and the keyboard separately if you like. I can't think of anything I don't like about the computer after using it for a couple of weeks. It's great!Update 6/30/19The computer developed a hardware fault about a month ago, which means it was still a pretty new computer. When I powered on the computer, the screen remained black and the speaker emitted a series of loud beeps. When I figured the beeps were a code, I looked it up and found that the problem was a hardware flaw that required a solution more complex than I could manage. I've had problems with computers before so have managed to fix my own computer when the problem is software or a memory problem. But this was beyond me and not worth fixing so I managed to wipe the computer (I hope) and recycled it. I don't need such serious problems with a new computer!\n",
#  '\nLove it!!!\n',
#  '\nI use this computer and 2 monitors for work. Everything is great so far. It came a day early. Packed very well with everything as advertised. Easy set up. Has 2 Samsung Monitors which I’m very happy about.\n',
#  '\nEasy to set up. Speed is excellent. It met my spec. that was required from my clients. I use this computer because I work from home as an independent contracted agent. Have recommended this package to several friends.\n',
#  '\nI received this item in 2 days and was packed very well. It was in good appearance and was happy with what I was looking at first look it looks used but not abused. Set up the system everything was there as far as cables for the monitors and tower. When I hit the power button on the desktop it would not come on. Monitors worked fine and came on for a few seconds but shut back down because the computer wood not come on. I was ready to send the unit back but that is a lot of packing and driving to a drop off place . so I decided to take the unit in to a repair shop to see if it may be a quick fix. Well the outcome was the motherboard was toast and needed to be replaced .So I had him replace the board for 119.00 Mat and Labor and then have him replace the hard drive With 500 gb SSD and he did it all for 199.00 it worked fine and very quick after that. So I ordered 16 gigs of ram from Amazon installed them and the unit screams now . The vid card is very poor and if you plan to use it for games you wont especially 3 D . So if you get one delivered and it works out of the box ,I think you will have a decent run of the mill desk top nothing special. I did call the tech support from where it was sent and they were overrun with calls. Wanted you to leave a # to be reached at and said they would get back to you .That was on a Friday they said they would get back no later than the following Mon. So so far I have invested 238.00 for unit 199.00 for motherboard 60 bucks on 16 G ram  Total of 20 G on unit now after I upgrade the vid card it will be great for gaming for the grand kids. good luck.\n',
#  '\nAmazing.  Love it.  Good price.  Can play Sims.  Two monitors one Tower keyboard and a mouse and wireless.  Easy setup up.  Mega awesome  for the price.\n',
#  "\nWe weren't sure what to expect for the price but we did not get the wifi adapter the seller said it came with. It was a Christmas gift so we purchased one right away hoping the seller would refund us. The seller never got back to is about this issue. We bought this PC for my son to game. It initially ran train sim but would not run fortnite. We had to purchase a new graphics card. It's hard for me to complain because even tho we had to spend a additional $100+ it still isn't a bad price. My review is poor because it did not hold up to the advertised product and the seller hasn't had good communication let alone assistance. It's worth the cost however, it was a Christmas gift for the purpose to play fortnite. It was very disappointing and frustrating that he couldn't play straight away. We ran out and bought the wifi adapter the next day but it took a little while to get the grafic card shipped to us. It was easy enough to install after watching how to YouTube videos.\n",
#  "\nIf I were to buy again, I'd get a bundle with better monitors. They work - a little outdated. Computer is fast, can't complain there....monitors, eh. For the money: 4 stars.\n",
#  "\nLove, love, love my new computer! Shipped right away and got it in two days! Packaged very well. Came with two matching, good quality Samsung monitors. The keyboard and mouse are low quality, but they were brand new and work great. Easy to set up right out of the box. WiFi adapter is not the best, and my computer is far from the router, so I'll buy a better one sometime. I use the computer for Quickbooks Online, Excel spreadsheets, and home computing. Great bang for your buck!\n",
#  '\nReceived in nicely packed box.  Both monitors are the same.  They had to send me a new wifi adapter cause the one that came with it did not work.  Now that i have receieved the wifi adapter, which works,  i am getting the blue screen of death.  Emailed customer,service so we shall see.  So far not too impressed\n',
#  '\nfor the price/ no complaints at all.  Love the computer\n',
#  '\ntook me a while, but thanks to OUTSTANDING tech support, I got it up and running and it performs great. The staff at Blair Technology were patient and walked me through what needed to be done.  Thanks, Blair Technology.\n']

# %%
len(reviews)
# Out:
# 94

# %%
import pandas as pd

# %%
# rev={'dates':dates, 'titles':titles, 'ratings':ratings, 'reviews':reviews, 'url':urls} #converting the reviews list into a dictionary

rev={'search_query':search_query_list, 'reviews' :reviews} #converting the reviews list into a dictionary

# %%
review_data=pd.DataFrame.from_dict(rev) #converting this dictionary into a dataframe

# %%
df = review_data.replace('\n','', regex=True)

# %%
df.shape
# Out:
# (4777, 2)

# %%
df
# Out:
#      search_query                                            reviews
# 0              tv  We have delightfully had several TCL 32" Roku ...
# 1              tv  Originally I purchased the 720p version of thi...
# 2              tv  Great picture. As a seasoned Roku veteran I ca...
# 3              tv  It arrived today on a Sunday evening.  It was ...
# 4              tv  Upgrading from a 32" TV because cable shows lo...
# ...           ...                                                ...
# 4772           tv  Bought this TV around the first of June, and s...
# 4773           tv  Christmas present.  Arrived in good condition....
# 4774           tv  Superior product at an amazing price. Quality ...
# 4775           tv  When buying for my home I always purchase vizi...
# 4776           tv  I've been very pleased with this Vizio TV over...
#
# [4777 rows x 2 columns]

# %%
writer= pd.ExcelWriter(search_query+'_review.xlsx')
df.to_excel(writer, 'Sheet1', index=False)
writer.save()

# %%
len(link)
# Out:
# 39
