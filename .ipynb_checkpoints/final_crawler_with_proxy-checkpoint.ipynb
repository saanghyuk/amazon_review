# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from urllib.parse import quote

# %%
# Input Search Query
SEARCH_QUERY = 'camera'

# %%
PROXY_CRAWL_TOKEN = 'jzZo4uXXrCQLlORHA6ARzw' #My API
# PROXY_CRAWL_TOKEN = 'K-9nDJsiR1tb0vbXVAaSOQ' #My API 2
#Hyunwoo API 
#

# %%
def get_proxy(url):
    quoted_url = quote(url)
    res = requests.get(f'https://api.proxycrawl.com/?token={PROXY_CRAWL_TOKEN}&url={quoted_url}')
    res.raise_for_status() # Raise error if it fails
    return res.content

# %%
#### A function to get the content of the page of required query
def search_in_amazon(search_query):
    url = f"https://www.amazon.com/s?k={search_query}"
    return get_proxy(url)

#### A function to get the contents of individual product pages using 'data-asin' number (unique identification number)
def search_asin(asin):
    url = f"https://www.amazon.com/dp/{asin}"
    return get_proxy(url)

#### A function to pass on the link of 'see all reviews' and extract the content
def search_reviews(review_link):
    url = f"https://www.amazon.com{review_link}"
    return get_proxy(url)

# %% [markdown]
# ### Product Name extraction

# %%
print("Start to extract product names")

product_names = []
data_asin = []
LAST_PAGE = 21
for i in range(1,LAST_PAGE):
    print(f"Iteration {i}/{LAST_PAGE}")
    html = search_in_amazon(SEARCH_QUERY+'&page='+str(i))
    soup = BeautifulSoup(html, 'html5lib')
    items = soup.findAll("span",{'class':'a-size-medium a-color-base a-text-normal'})
    if len(items) == 0:
        print(f"Warning: No product name found in this page")
    for i in items:
        product_names.append(i.text) # adding the product names to the list

    for i in soup.findAll("div", {"class":"s-result-item"}):
        if i['data-asin']:
            data_asin.append(i['data-asin'])

print(f"Finished: {len(product_names)} product names found")
# Out:
# Start to extract product names
# Iteration 1/21
# Iteration 2/21
# Iteration 3/21
# Iteration 4/21
# Iteration 5/21
# Iteration 6/21
# Iteration 7/21
# Iteration 8/21
# Iteration 9/21
# Iteration 10/21
# Iteration 11/21
# Iteration 12/21
# Iteration 13/21
# Iteration 14/21
# Iteration 15/21
# Iteration 16/21
# Iteration 17/21
# Iteration 18/21
# Iteration 19/21
# Iteration 20/21
# Finished: 306 product names found

# %%
len(product_names)
# Out:
# 306

# %% [markdown]
# When scrawling the all pages of product list in specific search query, I could discover that there are same products in the list. <br>
# Therefore, I needed to remove the same product in the list of ASIN.

# %%
print("Start to search asin")
# Out:
# Start to search asin

# %%
links = []

# %%
data_asin = list(set(data_asin)) # Leave unique values only

for i in range(len(data_asin)):
    print(f"Searching asin {i}/{len(data_asin)}")
    html = search_asin(data_asin[i])
    soup = BeautifulSoup(html, 'html5lib')
    for i in soup.findAll("a",{'data-hook':"see-all-reviews-link-foot"}):
        links.append(i['href'])
        
        
len(links)
# Out:
# Searching asin 0/276
# Searching asin 1/276
# Searching asin 2/276
# Searching asin 3/276
# Searching asin 4/276
# Searching asin 5/276
# Searching asin 6/276
# Searching asin 7/276
# Searching asin 8/276
# Searching asin 9/276
# Searching asin 10/276
# Searching asin 11/276
# Searching asin 12/276
# Searching asin 13/276
# Searching asin 14/276
# Searching asin 15/276
# Searching asin 16/276
# Searching asin 17/276
# Searching asin 18/276
# Searching asin 19/276
# Searching asin 20/276
# Searching asin 21/276
# Searching asin 22/276
# Searching asin 163/276
# Searching asin 164/276
# Searching asin 165/276
# Searching asin 166/276
# Searching asin 167/276
# Searching asin 168/276
# Searching asin 169/276
# Searching asin 170/276
# Searching asin 171/276
# Searching asin 172/276
# Searching asin 173/276
# Searching asin 174/276
# Searching asin 175/276
# Searching asin 176/276
# Searching asin 177/276
# Searching asin 178/276
# Searching asin 179/276
# Searching asin 180/276
# Searching asin 181/276
# Searching asin 182/276
# Searching asin 183/276
# Searching asin 184/276
# Searching asin 185/276
# Searching asin 186/276
# Searching asin 187/276
# Searching asin 188/276
# Searching asin 189/276
# Searching asin 190/276
# Searching asin 191/276
# Searching asin 192/276
# Searching asin 193/276
# Searching asin 194/276
# Searching asin 195/276
# Searching asin 196/276
# Searching asin 197/276
# Searching asin 198/276
# Searching asin 199/276
# Searching asin 200/276
# Searching asin 201/276
# Searching asin 202/276
# Searching asin 203/276
# Searching asin 204/276
# Searching asin 205/276
# Searching asin 206/276
# Searching asin 207/276
# Searching asin 208/276
# Searching asin 209/276
# Searching asin 210/276
# Searching asin 211/276
# Searching asin 212/276
# Searching asin 213/276
# Searching asin 214/276
# Searching asin 215/276
# Searching asin 216/276
# Searching asin 217/276
# Searching asin 218/276
# Searching asin 219/276
# Searching asin 220/276
# Searching asin 221/276
# Searching asin 222/276
# Searching asin 223/276
# Searching asin 224/276
# Searching asin 225/276
# Searching asin 226/276
# Searching asin 227/276
# Searching asin 228/276
# Searching asin 229/276
# Searching asin 230/276
# Searching asin 231/276
# Searching asin 232/276
# Searching asin 233/276
# Searching asin 234/276
# Searching asin 235/276
# Searching asin 236/276
# Searching asin 237/276
# Searching asin 238/276
# Searching asin 239/276
# Searching asin 240/276
# Searching asin 241/276
# Searching asin 242/276
# Searching asin 243/276
# Searching asin 244/276
# Searching asin 245/276
# Searching asin 246/276
# Searching asin 247/276
# Searching asin 248/276
# Searching asin 249/276
# Searching asin 250/276
# Searching asin 251/276
# Searching asin 252/276
# Searching asin 253/276
# Searching asin 254/276
# Searching asin 255/276
# Searching asin 256/276
# Searching asin 257/276
# Searching asin 258/276
# Searching asin 259/276
# Searching asin 260/276
# Searching asin 261/276
# Searching asin 262/276
# Searching asin 263/276
# Searching asin 264/276
# Searching asin 265/276
# Searching asin 266/276
# Searching asin 267/276
# Searching asin 268/276
# Searching asin 269/276
# Searching asin 270/276
# Searching asin 271/276
# Searching asin 272/276
# Searching asin 273/276
# Searching asin 274/276
# Searching asin 275/276
# 352

# %%
len(links)
# Out:
# 352

# %%
links = list(set(links))
print(f"Finished: {len(links)} links found")
# The number of link and the number of ASIN can be different, because there are many products which have no review.
# Out:
# Finished: 270 links found

# %%
print("Start to search reviews")
# urls=[]
# titles = []
search_query_list = []
reviews=[]
ratings=[]
# dates=[]
# Out:
# Start to search reviews

# %%
import time
import urllib.request
from urllib.error import HTTPError


while a<=1:
    print("web_raw_results"):
        
        


a=1;
while a<=3:
    try:
        web_raw_results = urllib2.urlopen(web_url)
        break
    except urllib.HTTPError, detail:
        if detail.errno == 500:
            print(f'500 error raise, currently {a}th trial')
            time.sleep(2)
            a+=1;
            continue
        else:
            print('error raise, not 500')
            raise

# %%
for i in range(len(links)):
    print(i)
    print(links[i])
# Out:
# 0
# /Polaroid-OneStep-Viewfinder-Lumintrail-Cleaning/product-reviews/B0813ZPMM8?reviewerType=all_reviews
# 1
# /MITMOR-Digital-Children-Camcorder-Birthday/product-reviews/B07YTZ5PWW?reviewerType=all_reviews
# 2
# /Canon-T7-Digital-Telephoto-Accessory/product-reviews/B07PBYQ62S?reviewerType=all_reviews
# 3
# /Wireless-Wire-Free-Battery-Powered-Surveillance-YI/product-reviews/B01CW47EG4?reviewerType=all_reviews
# 4
# /Wireless-Optical-Waterproof-Security-Surveillance/product-reviews/B07XRQ8YXV?reviewerType=all_reviews
# 5
# /Black-Memory-Expo-Basic-Accessory-Bundle/product-reviews/B06WWH9CVY?reviewerType=all_reviews
# 6
# /Camcorder-Vlogging-kicteck-Batteries-604s/product-reviews/B07MY3R7R9?reviewerType=all_reviews
# 7
# /Digital-Vlogging-Cameras-Rotation-Retractable/product-reviews/B084HQJMHL?reviewerType=all_reviews
# 8
# /Digital-Display-Student-Outdoor-Beginners/product-reviews/B07JK77M9H?reviewerType=all_reviews
# 9
# /Dragon-Touch-Vision-Underwater-Accessories/product-reviews/B07B2W96JH?reviewerType=all_reviews
# 10
# /HeimVision-HM245-Weatherproof-Surveillance-Detection/product-reviews/B07ZGBMVJ9?reviewerType=all_reviews
# 11
# /Canon-Digital-18-55mm-Stabilization-Accessory/product-reviews/B071RH4Y9W?reviewerType=all_reviews
# 12
# /Canon-T6-Digital-Telephoto-Accessory/product-reviews/B01D93Z89W?reviewerType=all_reviews
# 13
# /Security-Surveillance-Waterproof-Detection-Deterrent/product-reviews/B07Z3BZF35?reviewerType=all_reviews
# 14
# /TOGUARD-Waterproof-Wildlife-Monitoring-Security/product-reviews/B0843PCHVW?reviewerType=all_reviews
# 15
# /Ansel-Adams-Camera-Photography/product-reviews/0821221841?reviewerType=all_reviews
# 16
# /Fujifilm-instax-Instant-Camera-Bundle/product-reviews/B077BQ6KZ7?reviewerType=all_reviews
# 17
# /Amcrest-UltraHD-Weatherproof-3840x2160-IP8M-2597EB-28MM/product-reviews/B0837485XG?reviewerType=all_reviews
# 18
# /PIXPRO-AZ252-WH-Digital-Camera-Optical/product-reviews/B075P8QN2Y?reviewerType=all_reviews
# 19
# /Coolife-Wildlife-Infrared-Activated-Waterproof/product-reviews/B081ZZV854?reviewerType=all_reviews
# 20
# /Camcorder-Digital-Vlogging-Recorder-Batteries/product-reviews/B07YBCMXJJ?reviewerType=all_reviews
# 21
# /YI-Security-Surveillance-Monitor-Available/product-reviews/B01CW4AR9K?reviewerType=all_reviews
# 22
# /Fujifilm-Instant-40-Accessories-Filters/product-reviews/B074WH86Y2?reviewerType=all_reviews
# 23
# /Rechargeable-Battery-Powered-Waterproof-Detection-Compatible/product-reviews/B0816RV4BF?reviewerType=all_reviews
# 24
# /Kids-Camera-3-5-inch-Digital/product-reviews/B082ZFCNSD?reviewerType=all_reviews
# 25
# /PowerShot-Digital-Camera-Deal-Expo-Bundle/product-reviews/B07FN57LDS?reviewerType=all_reviews
# 26
# /Anpviz-Security-Varifocal-Surveillance-Waterproof/product-reviews/B07PFJRXV6?reviewerType=all_reviews
# 27
# /Mini-Camera-1080P-Recording-Memory/product-reviews/B07YDZJSW1?reviewerType=all_reviews
# 28
# /HONBOO-Wireless-Security-Surveillance-Activated/product-reviews/B082969SQ9?reviewerType=all_reviews
# 29
# /ZOSI-Camera-Housing-Outdoor-Security/product-reviews/B01ARJ2C2C?reviewerType=all_reviews
# 30
# /AIMASON-Digital-Rechargeable-Shockproof-Creative/product-reviews/B07Z8PBNDD?reviewerType=all_reviews
# 31
# /Camcorder-Microphone-Vlogging-Recorder-Controlle/product-reviews/B082TLSWTB?reviewerType=all_reviews
# 32
# /Canon-PowerShot-Digital-Stabilization-0-90in/product-reviews/B019UDHOMO?reviewerType=all_reviews
# 33
# /Canon-T7-18-55mm-3-5-5-6-Accessory/product-reviews/B07P15K8Q7?reviewerType=all_reviews
# 34
# /Ivosmart-Aluminum-Security-Surveillance-Mounting/product-reviews/B01N013UEM?reviewerType=all_reviews
# 35
# /YI-Security-Surveillance-Emergency-Response/product-reviews/B01CW4CEMS?reviewerType=all_reviews
# 36
# /Digital-Backpacking-Rechargeable-Students-Photography/product-reviews/B08344S37L?reviewerType=all_reviews
# 37
# /Camcorder-ZOHULU-Recorder-Microphone-Batteries/product-reviews/B07RTXRWV8?reviewerType=all_reviews
# 38
# /Canon-Digital-Camera-18-55mm-3-5-5-6/product-reviews/B06XNTPN8C?reviewerType=all_reviews
# 39
# /Canon-PowerShot-Digital-Camera-Battery/product-reviews/B01AKQ8A3C?reviewerType=all_reviews
# 40
# /Bare-Bones-Camera-Course-Video/product-reviews/1621535266?reviewerType=all_reviews
# 41
# /Underwater-Snorkeling-Waterproof-Rechargeable-Teenagers/product-reviews/B07W5B4XCT?reviewerType=all_reviews
# 42
# /Camera-Wireless-Hidden-WiFi-Remote/product-reviews/B0837S522C?reviewerType=all_reviews
# 43
# /Polaroid-SNAP-Touch-2-0-Built/product-reviews/B07FDJXSKQ?reviewerType=all_reviews
# 44
# /Joilcan-80-inch-Aluminum-Monopod-Lightweight/product-reviews/B07WRXQDM3?reviewerType=all_reviews
# 45
# /Security-Camera-Wireless-Surveillance-Monitor/product-reviews/B07YWB4VN8?reviewerType=all_reviews
# 46
# /TOGUARD-Mirror-Backup-Control-Waterproof/product-reviews/B082PFG8V7?reviewerType=all_reviews
# 47
# /Ricoh-WG-60-Waterproof-Digital-Black/product-reviews/B07JNPFGPY?reviewerType=all_reviews
# 48
# /Surveillance-TourAlle-Security-Detection-Waterproof/product-reviews/B07X11C956?reviewerType=all_reviews
# 49
# /HeimVision-HM241-Surveillance-Weatherproof-Monitoring/product-reviews/B07RKJDK65?reviewerType=all_reviews
# 50
# /Kodak-PIXPRO-FZ43-Red-Extendable/product-reviews/B078MMKD3N?reviewerType=all_reviews
# 51
# /Arlo-Pro-Add-Rechargeable-Included/product-reviews/B075P84FH9?reviewerType=all_reviews
# 52
# /PatrolMaster-Display-Waterproof-Shockproof-Enforcement/product-reviews/B07T8YPMRT?reviewerType=all_reviews
# 53
# /Digital-Camera-18-55MM-Accessory-Package/product-reviews/B082J6DHJB?reviewerType=all_reviews
# 54
# /Camcorder-Microphone-VideoSky-Vlogging-Recorder/product-reviews/B07Y1NV9RK?reviewerType=all_reviews
# 55
# /VanTop-Compatible-Waterproof-Accessories-Batteries/product-reviews/B082186KCS?reviewerType=all_reviews
# 56
# /PowerShot-Digital-Tabletop-Tripod-Vivitar-Cleaning/product-reviews/B07TV8M3F8?reviewerType=all_reviews
# 57
# /Sony-Mirrorless-Digital-Camera-28-70mm/product-reviews/B00PX8CNCM?reviewerType=all_reviews
# 58
# /Fujifilm-FinePix-Waterproof-Digital-Camera/product-reviews/B0797GG74B?reviewerType=all_reviews
# 59
# /Canon-18-55mm-3-5-5-6-SanDisk-Accessory/product-reviews/B01MQIFINS?reviewerType=all_reviews
# 60
# /Camera-Never-Lies-David-Rawlings/product-reviews/0785230696?reviewerType=all_reviews
# 61
# /PANASONIC-LUMIX-ZS60-Vario-Elmar-DMC-ZS60S/product-reviews/B0747TKQQZ?reviewerType=all_reviews
# 62
# /Blink-Outdoor-Security-storage-included/product-reviews/B07M8DTHGL?reviewerType=all_reviews
# 63
# /Introducing-Ring-Compact-security-two-way/product-reviews/B07Q9VBYV8?reviewerType=all_reviews
# 64
# /Expandable-Wireless-Security-Hiseeu-Surveillance/product-reviews/B07719HQQS?reviewerType=all_reviews
# 65
# /Lilexo-Mini-WiFi-Camera-Detection/product-reviews/B083QS53ZL?reviewerType=all_reviews
# 66
# /Canon-PowerShot-Digital-Optical-Stabilization/product-reviews/B019UDHX7A?reviewerType=all_reviews
# 67
# /Amcrest-Security-Wireless-Rechargeable-Weatherproof/product-reviews/B081S8K6BF?reviewerType=all_reviews
# 68
# /Surveillance-Starlight-Detection-Argus-PT/product-reviews/B07TYBS47Z?reviewerType=all_reviews
# 69
# /Monitor-Cameras-Extended-Temperature-Included/product-reviews/B07ZJ9B8KM?reviewerType=all_reviews
# 70
# /Wireless-Security-Reolink-Monitor-Two-Way/product-reviews/B07X81M2D2?reviewerType=all_reviews
# 71
# /Canon-PowerShot-Digital-Battery-Charger/product-reviews/B01AKQK34G?reviewerType=all_reviews
# 72
# /PIXPRO-Digital-Camera-Battery-Accessory/product-reviews/B079BK7SNF?reviewerType=all_reviews
# 73
# /Wireless-KAMTRON-Rechargeable-Detection-Waterproof/product-reviews/B07X75D9YY?reviewerType=all_reviews
# 74
# /Small-Hidden-Mini-Spy-Camera/product-reviews/B082W8BYQX?reviewerType=all_reviews
# 75
# /Victure-Dualband-Security-Monitor-Detection/product-reviews/B07YZ59QRR?reviewerType=all_reviews
# 76
# /GoPro-HERO7-White-Commerce-Waterproof/product-reviews/B083C5XVD7?reviewerType=all_reviews
# 77
# /Wyze-Indoor-Camera-Vision-Assistant/product-reviews/B07DGR98VQ?reviewerType=all_reviews
# 78
# /Canon-PowerShot-ELPH-190-Accessory/product-reviews/B01BUGMU0K?reviewerType=all_reviews
# 79
# /Detector-Wireless-Tracking-Listening-Frequency/product-reviews/B07Z3HQ3Z2?reviewerType=all_reviews
# 80
# /Wireless-ieGeek-Rechargeable-Surveillance-Detection/product-reviews/B07YFTK5NJ?reviewerType=all_reviews
# 81
# /Monitor-Remote-Pan-Tilt-Zoom-Camera-Infrared/product-reviews/B07N428WP1?reviewerType=all_reviews
# 82
# /QHOHQ-iPhone-Pro-Max-6-5/product-reviews/B082H1TK4V?reviewerType=all_reviews
# 83
# /Victure-Dual-Band-Detection-Wireless-Available/product-reviews/B07Z7D6MKN?reviewerType=all_reviews
# 84
# /Relohas-Wireless-Streaming-Upgraded-Activated/product-reviews/B07VDL1H3F?reviewerType=all_reviews
# 85
# /Camera-Wireless-Security-Surveillance-Waterproof/product-reviews/B07VT6D5DS?reviewerType=all_reviews
# 86
# /eufy-Security-eufyCam-Wireless-180-Day/product-reviews/B07W1HKYQK?reviewerType=all_reviews
# 87
# /ZOSI-1280TVL-Security-Waterproof-Aluminum/product-reviews/B00MXILRAE?reviewerType=all_reviews
# 88
# /Portable-Detection-Perfect-Security-Battery/product-reviews/B07X1YLC2L?reviewerType=all_reviews
# 89
# /Ubiquiti-Networks-UVC-G4-PRO-Protect-G4-PRO/product-reviews/B07R7F7KJM?reviewerType=all_reviews
# 90
# /PIXPRO-Friendly-FZ43-RD-Digital-Optical/product-reviews/B0195XJAZI?reviewerType=all_reviews
# 91
# /Fujifilm-Instax-Mini-Instant-Camera/product-reviews/B082YV9XG5?reviewerType=all_reviews
# 92
# /Expandable-Wireless-Security-Jecurity-Surveillance/product-reviews/B07Y9W7C3Z?reviewerType=all_reviews
# 93
# /UVC-G3-BULLET-3-UniFi-Video-Camera-Pack/product-reviews/B07THLX74K?reviewerType=all_reviews
# 94
# /Canon-18-55mm-75-300mm-Tripods-Accessory/product-reviews/B07LBV1V4D?reviewerType=all_reviews
# 95
# /5-Broken-Cameras-English-Subtitled/product-reviews/B00B03Z858?reviewerType=all_reviews
# 96
# /Paranormal-Caught-Camera-Season-2/product-reviews/B082WMXMGM?reviewerType=all_reviews
# 97
# /Security-Camera-Indoor-Wide-Angle-Detection/product-reviews/B07XTBQB1G?reviewerType=all_reviews
# 98
# /Nikon-COOLPIX-Digital-Camera-Built/product-reviews/B07HS3QSR9?reviewerType=all_reviews
# 99
# /Nikon-COOLPIX-Digital-Camera-Black/product-reviews/B01C3LEBW6?reviewerType=all_reviews
# 100
# /TENVIS-Security-Camera-Wireless-Surveillance/product-reviews/B071DDBT7M?reviewerType=all_reviews
# 101
# /PANASONIC-Megapixel-VARIO-SUMMILUX-Stabilization-DMC-LX10K/product-reviews/B01LZHIX13?reviewerType=all_reviews
# 102
# /Wireless-Security-Surveillance-Monitor-Two-Way/product-reviews/B07H2TZTHB?reviewerType=all_reviews
# 103
# /Hidden-Camera-1080P-Surveillance-Nanny/product-reviews/B07TXNP8JH?reviewerType=all_reviews
# 104
# /PANASONIC-Waterproof-Underwater-Camcorder-Stabilizer/product-reviews/B00RBG5QKA?reviewerType=all_reviews
# 105
# /Security-Wireless-Waterproof-Argus-Eco/product-reviews/B07R5YH7YN?reviewerType=all_reviews
# 106
# /Security-Recorder-Weatherproof-Surveillance-Included/product-reviews/B07ZH72ZGJ?reviewerType=all_reviews
# 107
# /Canon-PowerShot-180-Digital-Silver-Accessory/product-reviews/B01B6YDD1G?reviewerType=all_reviews
# 108
# /REOLINK-Rechargeable-Surveillance-Assistant-Detection/product-reviews/B07GBV9WG9?reviewerType=all_reviews
# 109
# /Canon-PowerShot-Digital-Camera-Optical/product-reviews/B019UDIAI6?reviewerType=all_reviews
# 110
# /Wireless-Streaming-Detection-Magnetic-Security/product-reviews/B0821GS69Q?reviewerType=all_reviews
# 111
# /Outdoor-Security-Camera-Reolink-Go/product-reviews/B07DW38ZGQ?reviewerType=all_reviews
# 112
# /Outdoor-Security-Surveillance-Detection-Waterproof/product-reviews/B083355KY2?reviewerType=all_reviews
# 113
# /Sony-DSCW800-Digital-Camera-Black/product-reviews/B00I8BIBCW?reviewerType=all_reviews
# 114
# /Wireless-UNIOJO-Megapixel-Waterproof-Surveillance/product-reviews/B081G9GZWV?reviewerType=all_reviews
# 115
# /Foldable-Quadcopter-Beginners-Altitude-Headless/product-reviews/B07V9QC7C7?reviewerType=all_reviews
# 116
# /Holy-Stone-Foldable-Quadcopter-Brushless/product-reviews/B07V3CLLCV?reviewerType=all_reviews
# 117
# /Olympus-Camera-14-42mm-Memory-enabled/product-reviews/B0751B835L?reviewerType=all_reviews
# 118
# /Canon-PowerShot-Digital-Camera-Battery/product-reviews/B01ANX34NS?reviewerType=all_reviews
# 119
# /Sony-DSCW800-Digital-Camera-Silver/product-reviews/B00I8BIC9E?reviewerType=all_reviews
# 120
# /KODAK-Digital-Replacement-Lithium-Ion-Accessories/product-reviews/B06XHSTRNV?reviewerType=all_reviews
# 121
# /Fujifilm-Waterproof-Advanced-Accessory-Floating/product-reviews/B07TCK58FR?reviewerType=all_reviews
# 122
# /Polaroid-Instant-Digital-Printing-Technology/product-reviews/B01CGVSFT8?reviewerType=all_reviews
# 123
# /Nikon-COOLPIX-Digital-Renewed-Sandisk/product-reviews/B082TT5RTG?reviewerType=all_reviews
# 124
# /Pre-installed-SMONET-Wireless-8-Channel-Surveillance/product-reviews/B082WXCFY3?reviewerType=all_reviews
# 125
# /Wansview-Wireless-Security-Camera-Detection/product-reviews/B07QKXM2D3?reviewerType=all_reviews
# 126
# /PANASONIC-Megapixel-20-1200mm-Stabilization-DC-FZ80K/product-reviews/B01MS16V42?reviewerType=all_reviews
# 127
# /Panasonic-Vario-ELMAR-F3-3-6-4-Megapixels-Sensitivity/product-reviews/B00KW5OKU4?reviewerType=all_reviews
# 128
# /Wireless-Security-Monitor-Assistant-Pack/product-reviews/B07ZR4G72T?reviewerType=all_reviews
# 129
# /Blink-Outdoor-Security-storage-included/product-reviews/B07MMZF2BF?reviewerType=all_reviews
# 130
# /Polaroid-Instant-Digital-Camera-Sticky-Backed/product-reviews/B07G1KXXVN?reviewerType=all_reviews
# 131
# /Campark-Camera-WiFi-Activated-Monitoring-Waterproof/product-reviews/B07XQCSZ54?reviewerType=all_reviews
# 132
# /Sony-Cyber-shot-DSC-H300-Digital-Camera/product-reviews/B00YSU4I5Q?reviewerType=all_reviews
# 133
# /ANNKE-Security-Hi-Resolution-Weather-Proof-perfectly/product-reviews/B0169YE894?reviewerType=all_reviews
# 134
# /Canon-PowerShot-Digital-Camera-Optical/product-reviews/B07QNYXZY6?reviewerType=all_reviews
# 135
# /Zen-Camera-Creative-Awakening-Photography/product-reviews/0399580336?reviewerType=all_reviews
# 136
# /Camera-Movement-Tracking-Activity-Android/product-reviews/B07DGBZDYT?reviewerType=all_reviews
# 137
# /Canon-T7-18-55mm-75-300mm-Professional/product-reviews/B07P14FB96?reviewerType=all_reviews
# 138
# /Security-Outdoor-Pre-Install-Recorder-Surveillance/product-reviews/B07MZQ7HR2?reviewerType=all_reviews
# 139
# /Ubiquiti-Networks-Network-Surveillance-Camera/product-reviews/B01D2OOODY?reviewerType=all_reviews
# 140
# /Victure-Dualband-Wireless-Security-Detection/product-reviews/B07WNLQCB9?reviewerType=all_reviews
# 141
# /Vlogging-Digital-YouTube-Retractable-Flashlight/product-reviews/B07YY6Y6XR?reviewerType=all_reviews
# 142
# /COOAU-Monitor-Wireless-Detection-Two-Way/product-reviews/B0811NJ7MC?reviewerType=all_reviews
# 143
# /Digital-Vlogging-Monitor-YouTube-Microphone/product-reviews/B07TMX9PSR?reviewerType=all_reviews
# 144
# /Wyze-Indoor-Wireless-Camera-Assistant/product-reviews/B076H3SRXG?reviewerType=all_reviews
# 145
# /Camcorder-Vlogging-Youtube-Microphone-Batteries/product-reviews/B07YFDD2TX?reviewerType=all_reviews
# 146
# /Wireless-Rechargeable-Battery-Powered-Detection-Waterproof/product-reviews/B07MVFYNSC?reviewerType=all_reviews
# 147
# /Fujifilm-FinePix-XP80-Waterproof-Yellow/product-reviews/B00S4KXNSO?reviewerType=all_reviews
# 148
# /Sony-Premium-Compact-Digital-28-100mm/product-reviews/B07PJW73CB?reviewerType=all_reviews
# 149
# /Victure-Security-Rechargeable-Detection-Waterproof/product-reviews/B07XKVGVWJ?reviewerType=all_reviews
# 150
# /Canon-Powershot-SX730-Digital-Camera/product-reviews/B071J55VXZ?reviewerType=all_reviews
# 151
# /Canon-PowerShot-Digital-Camera-Optical/product-reviews/B07FXXVC74?reviewerType=all_reviews
# 152
# /IPEVO-VZ-R-Document-Camera-5-883-4-01-00/product-reviews/B0784RZNKT?reviewerType=all_reviews
# 153
# /CasaCam-Wireless-Security-Touchscreen-Nightvision/product-reviews/B07P84YG61?reviewerType=all_reviews
# 154
# /Recording-Wireless-Security-Discrete-Rechargeable/product-reviews/B0842TKJ99?reviewerType=all_reviews
# 155
# /Sony-Premium-Compact-1-0-type-DSCRX100M7/product-reviews/B07VPQV7BY?reviewerType=all_reviews
# 156
# /Furbo-Dog-Camera-Designed-Compatible/product-reviews/B01FXC7JWQ?reviewerType=all_reviews
# 157
# /Wireless-Rechargeble-Surveillance-Detection-Waterproof/product-reviews/B082KWD94W?reviewerType=all_reviews
# 158
# /Victure-Activated-Waterproof-Wildlife-Infrared/product-reviews/B07KP9SPD4?reviewerType=all_reviews
# 159
# /AKASO-EK7000-Sports-Waterproof-Camcorder/product-reviews/B01HGM33HG?reviewerType=all_reviews
# 160
# /SARCCH-Surveillance-Wireless-Panoramic-Detection/product-reviews/B081D65CMV?reviewerType=all_reviews
# 161
# /Canon-Camera-18-55mm-75-300mm-Deluxe/product-reviews/B01DJDSAVU?reviewerType=all_reviews
# 162
# /Fujifilm-FinePix-XP120-Digital-Camera/product-reviews/B079SHSFVX?reviewerType=all_reviews
# 163
# /PIXPRO-Friendly-FZ53-BK-Digital-Optical/product-reviews/B01CG62CCE?reviewerType=all_reviews
# 164
# /Camcorder-Microphone-VideoSky-Vlogging-Recorder/product-reviews/B082MY8HMD?reviewerType=all_reviews
# 165
# /Security-Camera-WiFi-Detection-Monitoring/product-reviews/B07DPLF8KJ?reviewerType=all_reviews
# 166
# /Canon-PowerShot-Digital-Camera-Optical/product-reviews/B01FFACR50?reviewerType=all_reviews
# 167
# /ATian-Digital-Amazing-Rechargeable-Student/product-reviews/B07KQ1GFYD?reviewerType=all_reviews
# 168
# /Digital-Camera-Lyyes-Point-Shoot/product-reviews/B07FMYBTF6?reviewerType=all_reviews
# 169
# /Camera-Charger-Hidden-Premium-Surveillance/product-reviews/B07GCKZKX8?reviewerType=all_reviews
# 170
# /eufy-Security-Wireless-Requires-Compatibility/product-reviews/B07X41CXJ7?reviewerType=all_reviews
# 171
# /Fujifilm-Instax-Wide-300-Instant/product-reviews/B00TGOWK3Q?reviewerType=all_reviews
# 172
# /Wireless-Security-Activated-Outdoor-Apartment/product-reviews/B081NFWQ1V?reviewerType=all_reviews
# 173
# /Canon-Mirrorless-Camera-EF-M15-45mm-Video/product-reviews/B079YCW48M?reviewerType=all_reviews
# 174
# /Portable-Surveillance-Upgraded-Detection-Wireless/product-reviews/B0836GV1QP?reviewerType=all_reviews
# 175
# /Polaroid-Originals-Onestep-Coral-Camera/product-reviews/B07T8BJ4MC?reviewerType=all_reviews
# 176
# /Camcorder-Digital-Vlogging-YouTube-Degrees/product-reviews/B082NWPQ6P?reviewerType=all_reviews
# 177
# /Camera-Wireless-Hidden-Vision-Detection/product-reviews/B082KB1TM8?reviewerType=all_reviews
# 178
# /Victure-Activated-Upgraded-Waterproof-Wildlife/product-reviews/B07K53KL1G?reviewerType=all_reviews
# 179
# /Canon-PowerShot-Digital-Camera-Optical/product-reviews/B0835X8QXC?reviewerType=all_reviews
# 180
# /Minolta-Pixels-Digital-Optical-MN35Z-P/product-reviews/B0779KBH92?reviewerType=all_reviews
# 181
# /Waterproof-Underwater-Recorder-Flashlight-Snorkeling/product-reviews/B084JKW5P6?reviewerType=all_reviews
# 182
# /Digital-Vlogging-Youtube-Compact-Rotation/product-reviews/B07Y84XXBN?reviewerType=all_reviews
# 183
# /PIXPRO-Friendly-FZ152-RD-Digital-Optical/product-reviews/B01H3BSGU4?reviewerType=all_reviews
# 184
# /Canon-PowerShot-Digital-Camera-Optical/product-reviews/B07FPPZQK9?reviewerType=all_reviews
# 185
# /Amcrest-5-Megapixel-NightVision-Weatherproof-IP5M-T1179EW-28MM/product-reviews/B083G9KT4C?reviewerType=all_reviews
# 186
# /LUCKYCAM-Camcorder-Digital-Rotation-Recording/product-reviews/B07X7ZKQNL?reviewerType=all_reviews
# 187
# /Outdoor-Solar-Powered-Security-Wirefree-Go/product-reviews/B07TKKPTL3?reviewerType=all_reviews
# 188
# /Camera-1080P-Security-Wireless-Auto-Cruise-Activity/product-reviews/B07VBKHZL1?reviewerType=all_reviews
# 189
# /Ubiquiti-Networks-G3-Micro-Wireless-UVC-G3-MICRO/product-reviews/B077H91CM7?reviewerType=all_reviews
# 190
# /Wireless-Security-Outdoor-UOKIER-Rechargeable/product-reviews/B083338HMR?reviewerType=all_reviews
# 191
# /Amcrest-3840x2160-NightVision-Weatherproof-IP8M-2496EB/product-reviews/B07C7W91YR?reviewerType=all_reviews
# 192
# /SMONET-Security-Channel-Waterproof-Surveillance/product-reviews/B07ZK79JDK?reviewerType=all_reviews
# 193
# /Security-Surveillance-Detection-Waterproof-Deterrent/product-reviews/B084JHJ6DC?reviewerType=all_reviews
# 194
# /Amcrest-3840x2160-NightVision-Weatherproof-IP8M-T2499EW/product-reviews/B07RHQGS8V?reviewerType=all_reviews
# 195
# /RED-OWL-EYES-Spy-Camera/product-reviews/B082BJS3C2?reviewerType=all_reviews
# 196
# /Camera-ieGeek-Digital-Rechargeable-Storage/product-reviews/B083DVSH65?reviewerType=all_reviews
# 197
# /Digital-Camera-Vlogging-YouTube-Rotation/product-reviews/B07WHLRDSM?reviewerType=all_reviews
# 198
# /Vmotal-Rechargeable-Digital-Students-Cameras/product-reviews/B07JHL3FV6?reviewerType=all_reviews
# 199
# /Blink-Outdoor-Security-storage-included/product-reviews/B07MMZ2LTB?reviewerType=all_reviews
# 200
# /Nikon-COOLPIX-Digital-Camera-16-1MP/product-reviews/B07CPK1KSB?reviewerType=all_reviews
# 201
# /Campark-Camera-Waterproof-Monitoring-120°Detecting-Activated/product-reviews/B07BHLVXF7?reviewerType=all_reviews
# 202
# /Camera-Digital-Screen-Reader-Upgraded/product-reviews/B07VVBQDSL?reviewerType=all_reviews
# 203
# /Kodak-AZ401RD-Point-Digital-Camera/product-reviews/B073JVXDKV?reviewerType=all_reviews
# 204
# /All-new-Ring-Battery-security-two-way/product-reviews/B07Q6ZZFLS?reviewerType=all_reviews
# 205
# /Campark-Underwater-Photography-Rechargeable-Accessories/product-reviews/B01MXXP4EC?reviewerType=all_reviews
# 206
# /Vlogging-Camcorder-Function-Detection-2xBattery/product-reviews/B07YDQCHMR?reviewerType=all_reviews
# 207
# /SV3C-Wireless-Detection-Recording-Surveillance/product-reviews/B073GSSGWB?reviewerType=all_reviews
# 208
# /Outdoor-Security-30xOptical-Detection-AT-500PE20/product-reviews/B0828BP186?reviewerType=all_reviews
# 209
# /Nikon-COOLPIX-Digital-Camera-Black/product-reviews/B07TJ8NGX3?reviewerType=all_reviews
# 210
# /Spy-Camera-Wireless-Covert-Home-Detection-Surveillance-Camera/product-reviews/B07X7D3BC9?reviewerType=all_reviews
# 211
# /Wireless-Security-FUVISION-Waterproof-10400mAh/product-reviews/B07XYWD4MJ?reviewerType=all_reviews
# 212
# /ANNKE-Security-Definition-Weatherproof-Detection/product-reviews/B07SFDSFB2?reviewerType=all_reviews
# 213
# /Nikon-COOLPIX-P1000-Digital-Camera/product-reviews/B07F5HPXK4?reviewerType=all_reviews
# 214
# /Google-NC1104US-Indoor-Security-Camera/product-reviews/B00WBJGUA2?reviewerType=all_reviews
# 215
# /Moultrie-XV7000i-Cellular-Verizon-Network/product-reviews/B07NW7PQGC?reviewerType=all_reviews
# 216
# /Wireless-Security-Surveillance-Detection-Business/product-reviews/B07TQR22QS?reviewerType=all_reviews
# 217
# /GardePro-A3-Infrared-Detection-Waterproof/product-reviews/B07YTRR837?reviewerType=all_reviews
# 218
# /Canon-18-55mm-3-5-5-6-75-300mm-Accessory/product-reviews/B07P67Z2TM?reviewerType=all_reviews
# 219
# /Home-Zone-Security-Floodlight-Camera/product-reviews/B083ZPR969?reviewerType=all_reviews
# 220
# /Canon-75-300mm-Telephoto-Paintshop-Accessories/product-reviews/B07PBXLDZV?reviewerType=all_reviews
# 221
# /Moultrie-Mobile-XA7000i-Cellular-Network/product-reviews/B07NWD6J9B?reviewerType=all_reviews
# 222
# /Camcorder-Vlogging-Recorder-Camcorders-Batteries/product-reviews/B07Z3BKFQW?reviewerType=all_reviews
# 223
# /Camcorder-Vlogging-Microphone-Controller-Batteries/product-reviews/B07YBWBDDQ?reviewerType=all_reviews
# 224
# /Conico-Rechargeable-Surveillance-Detection-Waterproof/product-reviews/B0832SR3S9?reviewerType=all_reviews
# 225
# /Otoscope-Ear-Anykit-Upgraded-Endoscope-Adjustable/product-reviews/B07KPSLPRW?reviewerType=all_reviews
# 226
# /Canon-PowerShot-SX540-Replacement-Accessories/product-reviews/B07V2BQQB7?reviewerType=all_reviews
# 227
# /WOWGO-Kids-Digital-Camera-Rechargeable/product-reviews/B07ZKJV17F?reviewerType=all_reviews
# 228
# /Dog-Camera-Detection-Storage-Compatible/product-reviews/B07WZY8DXH?reviewerType=all_reviews
# 229
# /AbergBest-Rechargeable-Digital-Students-cameras/product-reviews/B078YR3MNK?reviewerType=all_reviews
# 230
# /Inspection-Fantronics-Waterproof-Borescope-Adjustable/product-reviews/B071HYRPND?reviewerType=all_reviews
# 231
# /TOGUARD-Wireless-Wire-Free-Rechargeable-Detection/product-reviews/B082PBLFPX?reviewerType=all_reviews
# 232
# /Lightweight-Aluminum-Capacity-Mounting-Traveling/product-reviews/B07TLWGXV7?reviewerType=all_reviews
# 233
# /Sony-DSCWX220-Digital-Camera-2-7-Inch/product-reviews/B00M9AB81O?reviewerType=all_reviews
# 234
# /Victure-Tracking-Detection-Wireless-Security/product-reviews/B07JB3CT33?reviewerType=all_reviews
# 235
# /Compact-Digital-Camera-Rechargeable-Seniors/product-reviews/B07SSSVCJJ?reviewerType=all_reviews
# 236
# /eufy-Security-Wireless-Requires-Compatibility/product-reviews/B07Z364PQ5?reviewerType=all_reviews
# 237
# /Digital-Photography-Rechargeable-Outdoor-Seniors/product-reviews/B07Z5QWL7M?reviewerType=all_reviews
# 238
# /VanTop-Waterproof-Lightweight-Rechargeable-Accessories/product-reviews/B0821FV3F6?reviewerType=all_reviews
# 239
# /Security-Wireless-Surveillance-Weatherproof-Detection/product-reviews/B082VPZ7SM?reviewerType=all_reviews
# 240
# /ZOSI-1920TVL-Security-Weatherproof-Surveillance/product-reviews/B00RWO0DZ4?reviewerType=all_reviews
# 241
# /Wireless-Rechargeable-Spotlight-Detection-Waterproof/product-reviews/B0815W8PQV?reviewerType=all_reviews
# 242
# /Outdoor-Camera-Wireless-I-Detection/product-reviews/B07X2M8KTR?reviewerType=all_reviews
# 243
# /Amazon-Cloud-Indoor-Security-Camera/product-reviews/B01MTOMIB4?reviewerType=all_reviews
# 244
# /ZOSI-Wireless-Security-Weatherproof-Surveillance/product-reviews/B017ISY85O?reviewerType=all_reviews
# 245
# /Security-Wireless-Fisheye-Panoramic-Detection/product-reviews/B08391WG8T?reviewerType=all_reviews
# 246
# /Photography-Masterclass-Your-Complete-Guide/product-reviews/B01LEK38SU?reviewerType=all_reviews
# 247
# /Wireless-Rechargeable-Detection-Waterproof-compatible/product-reviews/B07PM2NBGT?reviewerType=all_reviews
# 248
# /PowerShot-Digital-Transcend-Replacement-Cleaning/product-reviews/B07WW29MYW?reviewerType=all_reviews
# 249
# /HeimVision-HMD2-Rechargeable-Battery-Powered-Waterproof/product-reviews/B07T2Q7WJ5?reviewerType=all_reviews
# 250
# /Canon-Powershot-SX420-Digital-Camera/product-reviews/B079RQP1LJ?reviewerType=all_reviews
# 251
# /Q-See-Bullet-Security-Camera-QCN8093B/product-reviews/B07FBQNPVF?reviewerType=all_reviews
# 252
# /Security-COOAU-Surveillance-Detection-Waterproof/product-reviews/B07WVYV54Q?reviewerType=all_reviews
# 253
# /Campark-3000mAh-Portable-Charger-Waterproof/product-reviews/B083327HLX?reviewerType=all_reviews
# 254
# /Campark-Compatible-Android-Wildlife-Smartphone/product-reviews/B07W55GW8X?reviewerType=all_reviews
# 255
# /Olympus-Tough-TG-6-Waterproof-Camera/product-reviews/B07RC8HPHL?reviewerType=all_reviews
# 256
# /WOSPORTS-Wildlife-Scouting-Hunting-Waterproof/product-reviews/B081ZYLZSX?reviewerType=all_reviews
# 257
# /Canon-PowerShot-Flexible-Replacement-Protective/product-reviews/B00K47O5BY?reviewerType=all_reviews
# 258
# /PIXPRO-AZ251-WH-Digital-Camera-Optical/product-reviews/B00EEM5HC6?reviewerType=all_reviews
# 259
# /Wireless-Compatible-Hiseeu-Waterproof-Detection/product-reviews/B081PRVDJ3?reviewerType=all_reviews
# 260
# /8Channel-Hiseeu-Wireless-Waterproof-Recording/product-reviews/B07QM5996S?reviewerType=all_reviews
# 261
# /PIXPRO-AZ421-WH-Digital-Optical-White/product-reviews/B00M8C7U8I?reviewerType=all_reviews
# 262
# /Canon-PowerShot-Stabilized-Complete-Accessory/product-reviews/B00UIIDP06?reviewerType=all_reviews
# 263
# /Digital-Cameras-Beginners-Cameras-Travel-Camping/product-reviews/B07VGCXHXM?reviewerType=all_reviews
# 264
# /Digital-Backpacking-Rechargeable-Students-Photography/product-reviews/B082TTJ8JL?reviewerType=all_reviews
# 265
# /SanDisk-Ultra-128GB-Memory-SDSDUNC-128G-GN6IN/product-reviews/B0143IISD0?reviewerType=all_reviews
# 266
# /Kodak-PIXPRO-FZ43-Extendable-Protectors/product-reviews/B0789K78N1?reviewerType=all_reviews
# 267
# /Wireless-Security-Cameras-Waterproof-Surveillance/product-reviews/B0832TVDBB?reviewerType=all_reviews
# 268
# /Conico-Wireless-Detection-Service-Compatible/product-reviews/B082WW1SWW?reviewerType=all_reviews
# 269
# /Fujifilm-FinePix-Digital-Panorama-Dustproof/product-reviews/B079C5ZTBJ?reviewerType=all_reviews

# %%
for j in range(81, len(links)):
    if j==81:
        target = links[j]
        print(f"Searching reviews: {j}/{len(links)}, target is {target}")
        for k in range(191, 50000):
            html = search_reviews(f"{target}&pageNumber={k}")
            soup = BeautifulSoup(html, 'html5lib')
            if soup.find(
                'div',
                {"class" : "a-section a-spacing-top-large a-text-center no-reviews-section"}
            ):
                print(f'Page {k}: No more reviews, step to next link')
                break
            else:
#                 items = soup.select('span[data-hook="review-body"] > span')
                items = soup.select('div[data-hook="review"]')
#                 reviews_in_page = soup.select()
#                 ratings_in_page = soup.select('div.reviews-content span.a-icon-alt')
        
                prev_reviews_cnt = len(reviews)
                prev_ratings_cnt = len(ratings)
                
                for i in items:
                    ratings_in_page = i.find("i", {'data-hook':'review-star-rating'}).text
                    reviews_in_page = i.find('span', {'data-hook': 'review-body'}).text
                    if reviews_in_page == '':
                        # Ignore blank elements
                        continue
                    else:
#                         print('-----------------reviews-----------------')
#                         print(reviews_in_page.replace('\n', ''))
#                         print('-----------------ratings-----------------')
#                         print(ratings_in_page)
                        
                        ratings.append(ratings_in_page)
                        reviews.append(reviews_in_page.replace('\n', ''))
                        search_query_list.append(SEARCH_QUERY)
                        
                
                print(f"Page {k}: {len(ratings) - prev_ratings_cnt} ratings found")
                print(f"Page {k}: {len(reviews) - prev_reviews_cnt} reviews found")
                print(f"current number of ratings : {len(ratings)}")
                print(f"current number of reviews : {len(reviews)}")
                if len(ratings) != len(reviews):
                    print("something error")
                    sys.exit(1)
                print("---------------------------")

        
        
    else:
        target = links[j]
        print(f"Searching reviews: {j}/{len(links)}, target is {target}")
        for k in range(1, 50000):
            html = search_reviews(f"{target}&pageNumber={k}")
            soup = BeautifulSoup(html, 'html5lib')
            if soup.find(
                'div',
                {"class" : "a-section a-spacing-top-large a-text-center no-reviews-section"}
            ):
                print(f'Page {k}: No more reviews, step to next link')
                break
            else:
#                 items = soup.select('span[data-hook="review-body"] > span')
                items = soup.select('div[data-hook="review"]')
#                 reviews_in_page = soup.select()
#                 ratings_in_page = soup.select('div.reviews-content span.a-icon-alt')
        
                prev_reviews_cnt = len(reviews)
                prev_ratings_cnt = len(ratings)
                
                for i in reviews:
                    print(reviews)
                    
                    
                    
                for i in items:
                    ratings_in_page = i.find("i", {'data-hook':'review-star-rating'}).text
                    reviews_in_page = i.find('span', {'data-hook': 'review-body'}).text
                    if reviews_in_page == '':
                        # Ignore blank elements
                        continue
                    else:
#                         print('-----------------reviews-----------------')
#                         print(reviews_in_page.replace('\n', ''))
#                         print('-----------------ratings-----------------')
#                         print(ratings_in_page)
                        
                        ratings.append(ratings_in_page)
                        reviews.append(reviews_in_page.replace('\n', ''))
                        search_query_list.append(SEARCH_QUERY)
                        
                
                print(f"Page {k}: {len(ratings) - prev_ratings_cnt} ratings found")
                print(f"Page {k}: {len(reviews) - prev_reviews_cnt} reviews found")
                print(f"current number of ratings : {len(ratings)}")
                print(f"current number of reviews : {len(reviews)}")
                if len(ratings) != len(reviews):
                    print("something error")
                    sys.exit(1)
                print("---------------------------")

                
                
print(f"Finished: {len(reviews)} reviews found")
# Out:
# Searching reviews: 81/270, target is /Monitor-Remote-Pan-Tilt-Zoom-Camera-Infrared/product-reviews/B07N428WP1?reviewerType=all_reviews
# Page 191: 10 ratings found
# Page 191: 10 reviews found
# current number of ratings : 46779
# current number of reviews : 46779
# ---------------------------
# Page 192: 10 ratings found
# Page 192: 10 reviews found
# current number of ratings : 46789
# current number of reviews : 46789
# ---------------------------
# Page 193: 10 ratings found
# Page 193: 10 reviews found
# current number of ratings : 46799
# current number of reviews : 46799
# ---------------------------
# Page 194: 10 ratings found
# Page 194: 10 reviews found
# current number of ratings : 46809
# current number of reviews : 46809
# ---------------------------
# Page 195: 10 ratings found
# Page 195: 10 reviews found
# current number of ratings : 46819
# current number of reviews : 46819
# ---------------------------
# Page 196: 10 ratings found
# Page 196: 10 reviews found
# current number of ratings : 46829
# current number of reviews : 46829
# ---------------------------
# Page 197: 10 ratings found
# Page 197: 10 reviews found
# current number of ratings : 46839
# current number of reviews : 46839
# ---------------------------
# Page 198: 10 ratings found
# Page 198: 10 reviews found
# current number of ratings : 46849
# current number of reviews : 46849
# ---------------------------
# Page 199: 10 ratings found
# Page 199: 10 reviews found
# current number of ratings : 46859
# current number of reviews : 46859
# ---------------------------
# Page 200: 10 ratings found
# Page 200: 10 reviews found
# current number of ratings : 46869
# current number of reviews : 46869
# ---------------------------
# Page 201: 10 ratings found
# Page 201: 10 reviews found
# current number of ratings : 46879
# current number of reviews : 46879
# ---------------------------
# Page 202: 10 ratings found
# Page 202: 10 reviews found
# current number of ratings : 46889
# current number of reviews : 46889
# ---------------------------
# Page 203: 10 ratings found
# Page 203: 10 reviews found
# current number of ratings : 46899
# current number of reviews : 46899
# ---------------------------
# Page 204: 10 ratings found
# Page 204: 10 reviews found
# current number of ratings : 46909
# current number of reviews : 46909
# ---------------------------
# Page 205: 10 ratings found
# Page 205: 10 reviews found
# current number of ratings : 46919
# current number of reviews : 46919
# ---------------------------
# Page 206: 10 ratings found
# Page 206: 10 reviews found
# current number of ratings : 46929
# current number of reviews : 46929
# ---------------------------
# current number of reviews : 48001
# ---------------------------
# Page 50: 10 ratings found
# Page 50: 10 reviews found
# current number of ratings : 48011
# current number of reviews : 48011
# ---------------------------
# Page 51: 10 ratings found
# Page 51: 10 reviews found
# current number of ratings : 48021
# current number of reviews : 48021
# ---------------------------
# Page 52: 10 ratings found
# Page 52: 10 reviews found
# current number of ratings : 48031
# current number of reviews : 48031
# ---------------------------
# Page 53: 10 ratings found
# Page 53: 10 reviews found
# current number of ratings : 48041
# current number of reviews : 48041
# ---------------------------
# Page 54: 10 ratings found
# Page 54: 10 reviews found
# current number of ratings : 48051
# current number of reviews : 48051
# ---------------------------
# Page 55: 10 ratings found
# Page 55: 10 reviews found
# current number of ratings : 48061
# current number of reviews : 48061
# ---------------------------
# Page 56: 10 ratings found
# Page 56: 10 reviews found
# current number of ratings : 48071
# current number of reviews : 48071
# ---------------------------
# Page 57: 10 ratings found
# Page 57: 10 reviews found
# current number of ratings : 48081
# current number of reviews : 48081
# ---------------------------
# Page 58: 10 ratings found
# Page 58: 10 reviews found
# current number of ratings : 48091
# current number of reviews : 48091
# ---------------------------
# Page 59: 10 ratings found
# Page 59: 10 reviews found
# current number of ratings : 48101
# current number of reviews : 48101
# ---------------------------
# Page 60: 10 ratings found
# Page 60: 10 reviews found
# current number of ratings : 48111
# current number of reviews : 48111
# ---------------------------
# Page 61: 10 ratings found
# Page 61: 10 reviews found
# current number of ratings : 48121
# current number of reviews : 48121
# ---------------------------
# Page 62: 10 ratings found
# Page 62: 10 reviews found
# current number of ratings : 48131
# current number of reviews : 48131
# ---------------------------
# Page 63: 10 ratings found
# Page 63: 10 reviews found
# current number of ratings : 48141
# current number of reviews : 48141
# ---------------------------
# Page 64: 10 ratings found
# Page 64: 10 reviews found
# current number of ratings : 48151
# current number of reviews : 48151
# ---------------------------
# Page 65: 10 ratings found
# Page 65: 10 reviews found
# current number of ratings : 48161
# current number of reviews : 48161
# ---------------------------
# Page 66: 10 ratings found
# Page 66: 10 reviews found
# current number of ratings : 48171
# current number of reviews : 48171
# ---------------------------
# Page 67: 10 ratings found
# Page 67: 10 reviews found
# current number of ratings : 48181
# current number of reviews : 48181
# ---------------------------
# Page 68: 10 ratings found
# Page 68: 10 reviews found
# current number of ratings : 48191
# current number of reviews : 48191
# ---------------------------
# Page 69: 10 ratings found
# Page 69: 10 reviews found
# current number of ratings : 48201
# current number of reviews : 48201
# ---------------------------
# Page 70: 10 ratings found
# Page 70: 10 reviews found
# current number of ratings : 48211
# current number of reviews : 48211
# ---------------------------
# Page 71: 10 ratings found
# Page 71: 10 reviews found
# current number of ratings : 48221
# current number of reviews : 48221
# ---------------------------
# Page 72: 10 ratings found
# Page 72: 10 reviews found
# current number of ratings : 48231
# current number of reviews : 48231
# ---------------------------
# Page 73: 10 ratings found
# Page 73: 10 reviews found
# current number of ratings : 48241
# current number of reviews : 48241
# ---------------------------
# Page 74: 10 ratings found
# Page 74: 10 reviews found
# current number of ratings : 48251
# current number of reviews : 48251
# ---------------------------
# Page 75: 10 ratings found
# Page 75: 10 reviews found
# current number of ratings : 48261
# current number of reviews : 48261
# ---------------------------
# Page 76: 10 ratings found
# Page 76: 10 reviews found
# current number of ratings : 48271
# current number of reviews : 48271
# ---------------------------
# Page 77: 10 ratings found
# Page 77: 10 reviews found
# current number of ratings : 48281
# current number of reviews : 48281
# ---------------------------
# Page 78: 10 ratings found
# Page 78: 10 reviews found
# current number of ratings : 48291
# current number of reviews : 48291
# ---------------------------
# Page 79: 10 ratings found
# Page 79: 10 reviews found
# current number of ratings : 48301
# current number of reviews : 48301
# ---------------------------
# Page 80: 10 ratings found
# Page 80: 10 reviews found
# current number of ratings : 48311
# current number of reviews : 48311
# ---------------------------
# Page 81: 10 ratings found
# Page 81: 10 reviews found
# current number of ratings : 48321
# current number of reviews : 48321
# ---------------------------
# Page 82: 10 ratings found
# Page 82: 10 reviews found
# current number of ratings : 48331
# current number of reviews : 48331
# ---------------------------
# Page 83: 10 ratings found
# Page 83: 10 reviews found
# current number of ratings : 48341
# current number of reviews : 48341
# ---------------------------
# Page 84: 10 ratings found
# Page 84: 10 reviews found
# current number of ratings : 48351
# current number of reviews : 48351
# ---------------------------
# Page 85: 10 ratings found
# Page 85: 10 reviews found
# current number of ratings : 48361
# current number of reviews : 48361
# ---------------------------
# Page 86: 10 ratings found
# Page 86: 10 reviews found
# current number of ratings : 48371
# current number of reviews : 48371
# ---------------------------
# Page 87: 10 ratings found
# Page 87: 10 reviews found
# current number of ratings : 48381
# current number of reviews : 48381
# ---------------------------
# Page 88: 10 ratings found
# Page 88: 10 reviews found
# current number of ratings : 48391
# current number of reviews : 48391
# ---------------------------
# Page 89: 10 ratings found
# Page 89: 10 reviews found
# current number of ratings : 48401
# current number of reviews : 48401
# ---------------------------
# Page 90: 10 ratings found
# Page 90: 10 reviews found
# current number of ratings : 48411
# current number of reviews : 48411
# ---------------------------
# Page 91: 10 ratings found
# Page 91: 10 reviews found
# current number of ratings : 48421
# current number of reviews : 48421
# ---------------------------
# Page 92: 10 ratings found
# Page 92: 10 reviews found
# current number of ratings : 48431
# current number of reviews : 48431
# ---------------------------
# Page 93: 10 ratings found
# Page 93: 10 reviews found
# current number of ratings : 48441
# current number of reviews : 48441
# ---------------------------
# Page 94: 10 ratings found
# Page 94: 10 reviews found
# current number of ratings : 48451
# current number of reviews : 48451
# ---------------------------
# Page 95: 10 ratings found
# Page 95: 10 reviews found
# current number of ratings : 48461
# current number of reviews : 48461
# ---------------------------
# Page 96: 10 ratings found
# Page 96: 10 reviews found
# current number of ratings : 48471
# current number of reviews : 48471
# ---------------------------
# Page 97: 10 ratings found
# Page 97: 10 reviews found
# current number of ratings : 48481
# current number of reviews : 48481
# ---------------------------
# Page 98: 10 ratings found
# Page 98: 10 reviews found
# current number of ratings : 48491
# current number of reviews : 48491
# ---------------------------
# Page 99: 10 ratings found
# Page 99: 10 reviews found
# current number of ratings : 48501
# current number of reviews : 48501
# ---------------------------
# Page 100: 10 ratings found
# Page 100: 10 reviews found
# current number of ratings : 48511
# current number of reviews : 48511
# ---------------------------
# Page 101: 1 ratings found
# Page 101: 1 reviews found
# current number of ratings : 48512
# current number of reviews : 48512
# ---------------------------
# Page 102: No more reviews, step to next link
# Searching reviews: 88/270, target is /Portable-Detection-Perfect-Security-Battery/product-reviews/B07X1YLC2L?reviewerType=all_reviews
# Page 1: 10 ratings found
# Page 1: 10 reviews found
# current number of ratings : 48522
# current number of reviews : 48522
# ---------------------------
# Page 2: 10 ratings found
# Page 2: 10 reviews found
# current number of ratings : 48532
# current number of reviews : 48532
# ---------------------------
# Page 3: 10 ratings found
# Page 3: 10 reviews found
# current number of ratings : 48542
# current number of reviews : 48542
# ---------------------------
# Page 4: 10 ratings found
# Page 4: 10 reviews found
# current number of ratings : 48552
# current number of reviews : 48552
# ---------------------------
# Page 5: 10 ratings found
# Page 5: 10 reviews found
# current number of ratings : 48562
# current number of reviews : 48562
# ---------------------------
# Page 6: 10 ratings found
# Page 6: 10 reviews found
# current number of ratings : 48572
# current number of reviews : 48572
# ---------------------------
# Page 7: 10 ratings found
# Page 7: 10 reviews found
# current number of ratings : 48582
# current number of reviews : 48582
# ---------------------------
# Page 8: 10 ratings found
# Page 8: 10 reviews found
# current number of ratings : 48592
# current number of reviews : 48592
# ---------------------------
# Page 9: 10 ratings found
# Page 9: 10 reviews found
# current number of ratings : 48602
# current number of reviews : 48602
# ---------------------------
# Page 10: 10 ratings found
# Page 10: 10 reviews found
# current number of ratings : 48612
# current number of reviews : 48612
# ---------------------------
# Page 11: 10 ratings found
# Page 11: 10 reviews found
# current number of ratings : 48622
# current number of reviews : 48622
# ---------------------------
# Page 12: 10 ratings found
# Page 12: 10 reviews found
# current number of ratings : 48632
# current number of reviews : 48632
# ---------------------------
# Page 13: 10 ratings found
# Page 13: 10 reviews found
# current number of ratings : 48642
# current number of reviews : 48642
# ---------------------------
# Page 14: 10 ratings found
# Page 14: 10 reviews found
# current number of ratings : 48652
# current number of reviews : 48652
# ---------------------------
# Page 15: 10 ratings found
# Page 15: 10 reviews found
# current number of ratings : 48662
# current number of reviews : 48662
# ---------------------------
# Page 16: 10 ratings found
# Page 16: 10 reviews found
# current number of ratings : 48672
# current number of reviews : 48672
# ---------------------------
# Page 17: 10 ratings found
# Page 17: 10 reviews found
# current number of ratings : 48682
# current number of reviews : 48682
# ---------------------------
# Page 18: 10 ratings found
# Page 18: 10 reviews found
# current number of ratings : 48692
# current number of reviews : 48692
# ---------------------------
# Page 19: 10 ratings found
# Page 19: 10 reviews found
# current number of ratings : 48702
# current number of reviews : 48702
# ---------------------------
# Page 20: 10 ratings found
# Page 20: 10 reviews found
# current number of ratings : 48712
# current number of reviews : 48712
# ---------------------------
# Page 21: 10 ratings found
# Page 21: 10 reviews found
# current number of ratings : 48722
# current number of reviews : 48722
# ---------------------------
# Page 22: 10 ratings found
# Page 22: 10 reviews found
# current number of ratings : 48732
# current number of reviews : 48732
# ---------------------------
# Page 23: 10 ratings found
# Page 23: 10 reviews found
# current number of ratings : 48742
# current number of reviews : 48742
# ---------------------------
# Page 24: 10 ratings found
# Page 24: 10 reviews found
# current number of ratings : 48752
# current number of reviews : 48752
# ---------------------------
# Page 25: 10 ratings found
# Page 25: 10 reviews found
# current number of ratings : 48762
# current number of reviews : 48762
# ---------------------------
# Page 26: 10 ratings found
# Page 26: 10 reviews found
# current number of ratings : 48772
# current number of reviews : 48772
# ---------------------------
# Page 27: 10 ratings found
# Page 27: 10 reviews found
# current number of ratings : 48782
# current number of reviews : 48782
# ---------------------------
# Page 28: 10 ratings found
# Page 28: 10 reviews found
# current number of ratings : 48792
# current number of reviews : 48792
# ---------------------------
# Page 29: 10 ratings found
# Page 29: 10 reviews found
# current number of ratings : 48802
# current number of reviews : 48802
# ---------------------------
# Page 30: 10 ratings found
# Page 30: 10 reviews found
# current number of ratings : 48812
# current number of reviews : 48812
# ---------------------------
# Page 31: 10 ratings found
# Page 31: 10 reviews found
# current number of ratings : 48822
# current number of reviews : 48822
# ---------------------------
# Page 32: 10 ratings found
# Page 32: 10 reviews found
# current number of ratings : 48832
# current number of reviews : 48832
# ---------------------------
# Page 33: 10 ratings found
# Page 33: 10 reviews found
# current number of ratings : 48842
# current number of reviews : 48842
# ---------------------------
# Page 34: 10 ratings found
# Page 34: 10 reviews found
# current number of ratings : 48852
# current number of reviews : 48852
# ---------------------------
# Page 35: 10 ratings found
# Page 35: 10 reviews found
# current number of ratings : 48862
# current number of reviews : 48862
# ---------------------------
# Page 36: 7 ratings found
# Page 36: 7 reviews found
# current number of ratings : 48869
# current number of reviews : 48869
# ---------------------------
# Page 37: No more reviews, step to next link
# Searching reviews: 89/270, target is /Ubiquiti-Networks-UVC-G4-PRO-Protect-G4-PRO/product-reviews/B07R7F7KJM?reviewerType=all_reviews
# Page 1: 10 ratings found
# Page 1: 10 reviews found
# current number of ratings : 48879
# current number of reviews : 48879
# ---------------------------
# Page 2: 10 ratings found
# Page 2: 10 reviews found
# current number of ratings : 48889
# current number of reviews : 48889
# ---------------------------
# Page 3: 6 ratings found
# Page 3: 6 reviews found
# current number of ratings : 48895
# current number of reviews : 48895
# ---------------------------
# Page 4: No more reviews, step to next link
# Searching reviews: 90/270, target is /PIXPRO-Friendly-FZ43-RD-Digital-Optical/product-reviews/B0195XJAZI?reviewerType=all_reviews
# Page 1: 10 ratings found
# Page 1: 10 reviews found
# current number of ratings : 48905
# current number of reviews : 48905
# ---------------------------
# Page 2: 10 ratings found
# Page 2: 10 reviews found
# current number of ratings : 48915
# current number of reviews : 48915
# ---------------------------
# Page 3: 10 ratings found
# Page 3: 10 reviews found
# current number of ratings : 48925
# current number of reviews : 48925
# ---------------------------
# Page 4: 10 ratings found
# Page 4: 10 reviews found
# current number of ratings : 48935
# current number of reviews : 48935
# ---------------------------
# Page 5: 10 ratings found
# Page 5: 10 reviews found
# current number of ratings : 48945
# current number of reviews : 48945
# ---------------------------
# Page 6: 10 ratings found
# Page 6: 10 reviews found
# current number of ratings : 48955
# current number of reviews : 48955
# ---------------------------
# Page 7: 10 ratings found
# Page 7: 10 reviews found
# current number of ratings : 48965
# current number of reviews : 48965
# ---------------------------
# Page 8: 10 ratings found
# Page 8: 10 reviews found
# current number of ratings : 48975
# current number of reviews : 48975
# ---------------------------
# Page 9: 10 ratings found
# Page 9: 10 reviews found
# current number of ratings : 48985
# current number of reviews : 48985
# ---------------------------
# Page 10: 10 ratings found
# Page 10: 10 reviews found
# current number of ratings : 48995
# current number of reviews : 48995
# ---------------------------
# Page 11: 10 ratings found
# Page 11: 10 reviews found
# current number of ratings : 49005
# current number of reviews : 49005
# ---------------------------
# Page 12: 10 ratings found
# Page 12: 10 reviews found
# current number of ratings : 49015
# current number of reviews : 49015
# ---------------------------
# Page 13: 10 ratings found
# Page 13: 10 reviews found
# current number of ratings : 49025
# current number of reviews : 49025
# ---------------------------
# Page 14: 10 ratings found
# Page 14: 10 reviews found
# current number of ratings : 49035
# current number of reviews : 49035
# ---------------------------
# Page 15: 10 ratings found
# Page 15: 10 reviews found
# current number of ratings : 49045
# current number of reviews : 49045
# ---------------------------
# Page 16: 10 ratings found
# Page 16: 10 reviews found
# current number of ratings : 49055
# current number of reviews : 49055
# ---------------------------
# Page 17: 10 ratings found
# Page 17: 10 reviews found
# current number of ratings : 49065
# current number of reviews : 49065
# ---------------------------
# Page 18: 10 ratings found
# Page 18: 10 reviews found
# current number of ratings : 49075
# current number of reviews : 49075
# ---------------------------
# Page 19: 10 ratings found
# Page 19: 10 reviews found
# current number of ratings : 49085
# current number of reviews : 49085
# ---------------------------
# Page 20: 10 ratings found
# Page 20: 10 reviews found
# current number of ratings : 49095
# current number of reviews : 49095
# ---------------------------
# Page 21: 10 ratings found
# Page 21: 10 reviews found
# current number of ratings : 49105
# current number of reviews : 49105
# ---------------------------
# Page 22: 10 ratings found
# Page 22: 10 reviews found
# current number of ratings : 49115
# current number of reviews : 49115
# ---------------------------
# Page 23: 10 ratings found
# Page 23: 10 reviews found
# current number of ratings : 49125
# current number of reviews : 49125
# ---------------------------
# Page 24: 10 ratings found
# Page 24: 10 reviews found
# current number of ratings : 49135
# current number of reviews : 49135
# ---------------------------
# Page 25: 10 ratings found
# Page 25: 10 reviews found
# current number of ratings : 49145
# current number of reviews : 49145
# ---------------------------
# Page 26: 10 ratings found
# Page 254: 10 reviews found
# current number of ratings : 52065
# current number of reviews : 52065
# ---------------------------
# Page 255: 10 ratings found
# Page 255: 10 reviews found
# current number of ratings : 52075
# current number of reviews : 52075
# ---------------------------
# Page 256: 10 ratings found
# Page 256: 10 reviews found
# current number of ratings : 52085
# current number of reviews : 52085
# ---------------------------
# Page 257: 10 ratings found
# Page 257: 10 reviews found
# current number of ratings : 52095
# current number of reviews : 52095
# ---------------------------
# Page 258: 10 ratings found
# Page 258: 10 reviews found
# current number of ratings : 52105
# current number of reviews : 52105
# ---------------------------
# Page 259: 10 ratings found
# Page 259: 10 reviews found
# current number of ratings : 52115
# current number of reviews : 52115
# ---------------------------
# Page 260: 10 ratings found
# Page 260: 10 reviews found
# current number of ratings : 52125
# current number of reviews : 52125
# ---------------------------
# Page 261: 10 ratings found
# Page 261: 10 reviews found
# current number of ratings : 52135
# current number of reviews : 52135
# ---------------------------
# Page 262: 10 ratings found
# Page 262: 10 reviews found
# current number of ratings : 52145
# current number of reviews : 52145
# ---------------------------
# Page 263: 10 ratings found
# Page 263: 10 reviews found
# current number of ratings : 52155
# current number of reviews : 52155
# ---------------------------
# Page 264: 10 ratings found
# Page 264: 10 reviews found
# current number of ratings : 52165
# current number of reviews : 52165
# ---------------------------
# Page 265: 10 ratings found
# Page 265: 10 reviews found
# current number of ratings : 52175
# current number of reviews : 52175
# ---------------------------
# Page 266: 10 ratings found
# Page 266: 10 reviews found
# current number of ratings : 52185
# current number of reviews : 52185
# ---------------------------
# Page 267: 10 ratings found
# Page 267: 10 reviews found
# current number of ratings : 52195
# current number of reviews : 52195
# ---------------------------
# Page 268: 10 ratings found
# Page 268: 10 reviews found
# current number of ratings : 52205
# current number of reviews : 52205
# ---------------------------
# Page 269: 10 ratings found
# Page 269: 10 reviews found
# current number of ratings : 52215
# current number of reviews : 52215
# ---------------------------
# Page 270: 10 ratings found
# Page 270: 10 reviews found
# current number of ratings : 52225
# current number of reviews : 52225
# ---------------------------
# Page 271: 10 ratings found
# Page 271: 10 reviews found
# current number of ratings : 52235
# current number of reviews : 52235
# ---------------------------
# Page 272: 10 ratings found
# Page 272: 10 reviews found
# current number of ratings : 52245
# current number of reviews : 52245
# ---------------------------
# Page 273: 10 ratings found
# Page 273: 10 reviews found
# current number of ratings : 52255
# current number of reviews : 52255
# ---------------------------
# Page 274: 10 ratings found
# Page 274: 10 reviews found
# current number of ratings : 52265
# current number of reviews : 52265
# ---------------------------
# Page 275: 10 ratings found
# Page 275: 10 reviews found
# current number of ratings : 52275
# current number of reviews : 52275
# ---------------------------
# Page 276: 10 ratings found
# Page 276: 10 reviews found
# current number of ratings : 52285
# current number of reviews : 52285
# ---------------------------
# Page 277: 10 ratings found
# Page 277: 10 reviews found
# current number of ratings : 52295
# current number of reviews : 52295
# ---------------------------
# Page 278: 10 ratings found
# Page 278: 10 reviews found
# current number of ratings : 52305
# current number of reviews : 52305
# ---------------------------

# %%
print(reviews[-10:])
print(ratings[-10:])
# Out:
# ['        great monitor! the only downside is the battery on the parent monitor dies very quickly! picture, night vision, music, and zoom/tilt all works fantastically! temp is nice to see. i don’t use the mic but i know it works well. other than that, i don’t use the other features.  ', '        The product works great! Especially love the nose detector! Plus the quality its great and the quality of the picture on the monitor works wonders. Also love how it auto adjust to night vision. I can play music and talk through the monitor. Very helpful cause there’s no need for internet connections & so it makes me easy to take it to other peoples house even if they have wifi connections.  ', '        I LOVE that I can see my baby in the dark, and I can adjust the noise sensitivity do register her crying and not just talking. And when she’s quite the screen turns off. I love how easy it was to install!! I also love that it has a temp alarm that will alert me if it gets to hot or cold in her room!! And if she does wake up I can play a lullaby, or talk to her through the monitor!! Only regret is not buying it sooner!!  ', '        I just received this from my baby registry. The view is clear and the monitor is very user-friendly. I’m still figuring out how to use it, as baby isn’t here yet, but am excited to use it!  ', '        The monitor itself is fine until it quits working after Only months of use. The customer service in the other hand, is TERRIBLE! They string you along for months only to leave you unanswered and they do not honor their warranty. I recommend buying a different monitor if you’d like it for more than 5 months, because you’llEnd up buying another one anyways when they leave you empty handed.  ', '        This monitor is great! Not only is the monitor easy set up and install, the quality of the picture and the night vision is great! Another feature I love is the intercom/voice feature. This monitor has a press to talk mic function and a lullaby function that I didn’t realize I needed but cannot imagine not having! This is a great monitor and the value far exceeds the cost!  ', '        This was a gift.  The baby hasn’t been born yet, but they have played with it and live it.  ', '        Great monitor—perfect for watching baby day or night!  ', '        Easy setup. Very easy user interface. No feedback when you get close.  ', '        Very upset about this monitor. My sister got it for me as a baby shower gift and when we finally got it hooked up and went to use it the sound doesn’t work! We tried resetting it, plugging it in again, and nothing works. For the price of this monitor you would think it shouldn’t be faulty.  ']
# ['4.0 out of 5 stars', '5.0 out of 5 stars', '5.0 out of 5 stars', '5.0 out of 5 stars', '1.0 out of 5 stars', '5.0 out of 5 stars', '5.0 out of 5 stars', '5.0 out of 5 stars', '5.0 out of 5 stars', '2.0 out of 5 stars']

# %%
print(len(reviews))
print(len(ratings))
# Out:
# 46769
# 46769

# %%
reviews_copy=reviews
ratings_copy=ratings

# %%
del reviews_copy[-1]
del ratings_copy[-1]

# %%
len(reviews_copy)
# Out:
# 54437

# %%
print("Start to generate report")
# rev={'dates':dates, 'titles':titles, 'ratings':ratings, 'reviews':reviews, 'url':urls} #converting the reviews list into a dictionary

rev={'search_query':search_query_list, 'ratings':ratings, 'reviews' :reviews} #converting the reviews list into a dictionary
review_data=pd.DataFrame.from_dict(rev) #converting this dictionary into a dataframe



df = review_data.replace('\n','', regex=True)
# Out:
# Start to generate report

# %%
df1=df
df1['reviews']= df1['reviews'].str.strip()

# %%
df1.head()
# Out:
#   search_query             ratings  \
# 0     computer  1.0 out of 5 stars
# 1     computer  5.0 out of 5 stars
# 2     computer  5.0 out of 5 stars
# 3     computer  5.0 out of 5 stars
# 4     computer  4.0 out of 5 stars
#
#                                              reviews
# 0  Do not buy anything renewed by the ReGadget co...
# 1  I purchased this from Refurb Ninja. Since this...
# 2  I’m really pleased with my purchase of this li...
# 3  The unit worked good  right out of the box. I ...
# 4  Super Easy start up would have been easier had...

# %%
writer = pd.ExcelWriter(SEARCH_QUERY+'_review.xlsx')
df1.to_excel(writer, 'Sheet1', index=False)
writer.save()
print("Success")
# Out:
# Success
